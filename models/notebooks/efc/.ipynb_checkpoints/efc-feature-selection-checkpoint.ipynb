# %% [markdown]
# # Experiment x-4
# Applying feature selection to elliptic dataset

# %%
from efc import EnergyBasedFlowClassifier

# %%
from matplotlib import pyplot as plt

# %%
from sklearn.metrics import (
    f1_score,
    accuracy_score,
    precision_score,
    recall_score,
    roc_auc_score,
    confusion_matrix
)

# %%
results_efc = 'results/efc/experiment-x-4'

# %%
# make experiments results dir if not exists
if not os.path.exists(results_efc):
    os.makedirs(results_efc)

# %% [markdown]
# ## Common Functions

# %%
def calculate_model_score(y_true, y_pred):
    return {
        "accuracy": accuracy_score(y_true, y_pred),
        "f1": f1_score(y_true, y_pred, average="weighted"),
        "f1_micro": f1_score(y_true, y_pred, average="micro"),
        "f1_macro": f1_score(y_true, y_pred, average="macro"),
        "precision": precision_score(y_true, y_pred, average="weighted"),
        "recall": recall_score(y_true, y_pred, average="weighted"),
    }

# %%
def train_test_from_splitted(X_train, y_train, X_test, y_test, return_df=False):
    df_train = pd.concat([X_train, y_train], axis=1)
    df_test = pd.concat([X_test, y_test], axis=1)
    df = pd.concat([df_train, df_test])
    X = df.drop(['class'], axis=1)
    y = df['class']

    if return_df:
        df_train = pd.concat([X_train, y_train], axis=1)
        df_test = pd.concat([X_test, y_test], axis=1)
        df_new = pd.concat([df_train, df_test])
        return df_new

    return X, y

# %%
def recreate_original_df():
    last_time_step = 49
    last_train_time_step = 34
    only_labeled = True
    X_train, X_test, y_train, y_test = run_elliptic_preprocessing_pipeline(last_train_time_step=last_train_time_step,
                                                                             last_time_step=last_time_step,
                                                                             only_labeled=only_labeled)
    df_train = pd.concat([X_train, y_train], axis=1)
    df_test = pd.concat([X_test, y_test], axis=1)
    df = pd.concat([df_train, df_test])

    return df

# %%
from sklearn.model_selection import train_test_split as sklearn_train_test_split

def train_test_from_x_y(X, y, last_train_time_step, last_time_step):
    X_train_df, X_test_df, y_train, y_test = sklearn_train_test_split(X, y, random_state=139, stratify=y, shuffle=True, test_size=0.3)

    return X_train_df, X_test_df, y_train, y_test

# %% [markdown]
# ## Dataset

# %%
import os
import sys

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
ROOT_DIR = os.getcwd()
sys.path.insert(0, ROOT_DIR)

# %%
def combine_dataframes(df_classes, df_features, only_labeled=True):
    df_combined = pd.merge(
        df_features, df_classes, left_on="id", right_on="txId", how="left"
    )
    if only_labeled == True:
        df_combined = df_combined[df_combined["class"] != 2].reset_index(drop=True)
    df_combined.drop(columns=["txId"], inplace=True)

    return df_combined

# %%
def rename_classes(df_classes):
    df_classes.replace({"class": {"1": 1, "2": 0, "unknown": 2}}, inplace=True)

    return df_classes

# %%
def rename_features(df_features):
    df_features.columns = (
        ["id", "time_step"]
        + [f"trans_feat_{i}" for i in range(93)]
        + [f"agg_feat_{i}" for i in range(72)]
    )

    return df_features

# %%
def import_elliptic_data_from_csvs():
    df_classes = pd.read_csv(
        os.path.join(ROOT_DIR, "datasets/elliptic/elliptic_txs_classes.csv")
    )
    df_edges = pd.read_csv(
        os.path.join(ROOT_DIR, "datasets/elliptic/elliptic_txs_edgelist.csv")
    )
    df_features = pd.read_csv(
        os.path.join(ROOT_DIR, "datasets/elliptic/elliptic_txs_features.csv"),
        header=None,
    )

    return df_classes, df_edges, df_features

# %%
def setup_train_test_idx(
    X, last_train_time_step, last_time_step, aggregated_timestamp_column="time_step"
):
    """The aggregated_time_step_column needs to be a column with integer values, such as year, month or day"""

    split_timesteps = {}

    split_timesteps["train"] = list(range(last_train_time_step + 1))
    split_timesteps["test"] = list(range(last_train_time_step + 1, last_time_step + 1))

    train_test_idx = {}
    train_test_idx["train"] = X[
        X[aggregated_timestamp_column].isin(split_timesteps["train"])
    ].index
    train_test_idx["test"] = X[
        X[aggregated_timestamp_column].isin(split_timesteps["test"])
    ].index

    return train_test_idx

# %%
def train_test_split(X, y, train_test_idx):
    X_train_df = X.loc[train_test_idx["train"]]
    X_test_df = X.loc[train_test_idx["test"]]

    y_train = y.loc[train_test_idx["train"]]
    y_test = y.loc[train_test_idx["test"]]

    return X_train_df, X_test_df, y_train, y_test

# %%
def load_elliptic_data(only_labeled=True, drop_node_id=True):
    df_classes, df_edges, df_features = import_elliptic_data_from_csvs()
    df_features = rename_features(df_features)
    df_classes = rename_classes(df_classes)
    df_combined = combine_dataframes(df_classes, df_features, only_labeled)

    if drop_node_id == True:
        X = df_combined.drop(columns=["id", "class"])
    else:
        X = df_combined.drop(columns="class")

    y = df_combined["class"]

    return X, y

# %%
def load_elliptic_data(only_labeled=True, drop_node_id=True):
    df_classes, df_edges, df_features = import_elliptic_data_from_csvs()
    df_features = rename_features(df_features)
    df_classes = rename_classes(df_classes)
    df_combined = combine_dataframes(df_classes, df_features, only_labeled)

    if drop_node_id == True:
        X = df_combined.drop(columns=["id", "class"])
    else:
        X = df_combined.drop(columns="class")

    y = df_combined["class"]

    return X, y

# %%
def run_elliptic_preprocessing_pipeline(
    last_train_time_step, last_time_step, only_labeled=True, drop_node_id=True,
    only_x_y=False
):
    X, y = load_elliptic_data(only_labeled, drop_node_id)
    if only_x_y:
        return X, y
    train_test_idx = setup_train_test_idx(X, last_train_time_step, last_time_step)
    X_train_df, X_test_df, y_train, y_test = train_test_split(X, y, train_test_idx)

    return X_train_df, X_test_df, y_train, y_test

# %% [markdown]
# ## Decreasing Features
# The original dataset contains 167 features, making EFC not learning well the anomolous class. We want to decrease the number of features in an atempt to improve EFC learning on malicious class.

# %% [markdown]
# ### Feature selection wit sklearn

# %% [markdown]
# #### feature selection score function f_classif k = 16

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import chi2

# %%
# Elliptic data set timestep
last_time_step = 49
last_train_time_step = 34
only_labeled = True

# %%
X_1, y_1 = run_elliptic_preprocessing_pipeline(
    last_train_time_step=last_train_time_step,
    last_time_step=last_time_step,
    only_x_y=True
)
# Out:
# /var/folders/8b/c9dvlw851kx2vf3r7gc5gbbh0000gn/T/ipykernel_47895/3533226547.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_classes.replace({"class": {"1": 1, "2": 0, "unknown": 2}}, inplace=True)

# %%
X_1.shape
# Out:
# (46564, 166)

# %% [markdown]
# for chi2 scoring function, X values must be non-negative

# %%
X_new_1 = SelectKBest(f_classif, k=16).fit_transform(X_1, y_1)

# %%
X_new_1.shape
# Out:
# (46564, 16)

# %%
X_new_1
# Out:
# array([[-0.41400813,  4.18119239,  4.34663973, ..., -1.0598684 ,
#         -0.21681436, -0.57709938],
#        [-0.27112413,  3.68552898,  3.63375331, ..., -1.0598684 ,
#         -0.21681436, -0.57709938],
#        [-0.41395175, -0.48829574, -0.23255262, ..., -1.0598684 ,
#         -0.21681436, -0.57709938],
#        ...,
#        [-0.41388414,  0.66986851,  1.77421454, ..., -0.45332953,
#          0.3276244 ,  1.70962271],
#        [ 3.15409476,  2.47923489, -0.23255262, ..., -1.0598684 ,
#         -0.21681436, -0.57709938],
#        [ 0.83152309,  0.68956737,  0.02127675, ..., -1.0598684 ,
#          1.74789942,  1.26124583]])

# %% [markdown]
# ##### EFC with feature selection

# %%
df_fs_1 = pd.DataFrame(data=X_new_1)

# %%
df_fs_1
# Out:
#              0         1         2         3         4         5         6   \
# 0     -0.414008  4.181192  4.346640  1.777963  0.216750  0.216948  0.717108
# 1     -0.271124  3.685529  3.633753  1.349956  0.216750  0.216948  0.717108
# 2     -0.413952 -0.488296 -0.232553 -0.467503 -0.264408 -0.262405 -0.259232
# 3     -0.414002 -0.488337 -0.232553 -0.467551 -0.263830 -0.262097 -0.258919
# 4     -0.413200  2.759210  5.899000  2.030537 -0.264425 -0.262424 -0.259251
# ...         ...       ...       ...       ...       ...       ...       ...
# 46559  1.755516  1.316043 -0.232553  1.614191  8.063037  8.556144  2.734597
# 46560  1.650708  1.228874 -0.232553  1.513623 -0.264408 -0.262405 -0.259213
# 46561 -0.413884  0.669869  1.774215  0.335680 -0.264425 -0.262424 -0.259251
# 46562  3.154095  2.479235 -0.232553  2.956185  2.018825  2.295907  2.346092
# 46563  0.831523  0.689567  0.021277  0.788639 -0.264335 -0.262321 -0.259147
#
#              7         8         9         10        11        12        13  \
# 0      0.810879 -0.694235  2.084651  0.856163 -0.163577 -0.425896 -1.059868
# 1      0.810879 -0.694235  2.084651  1.152253 -0.163577 -0.425896 -1.059868
# 2     -0.711861 -0.633648 -0.676279 -0.349933 -0.168742 -0.968903 -1.059868
# 3     -0.415344 -0.275094 -0.411789 -0.349933 -0.168742 -0.968903 -1.059868
# 4     -0.761259 -0.693529 -0.720231  0.682652 -0.168742 -0.968903 -1.059868
# ...         ...       ...       ...       ...       ...       ...       ...
# 46559  2.042339  1.006039  1.186074 -0.349933 -0.123309 -0.968903  0.951793
# 46560 -0.761253 -0.694235 -0.719700 -0.349933  3.059448  2.289138 -1.059868
# 46561 -0.761754 -0.693987 -0.720777  0.682652  0.188319  1.746131 -0.453330
# 46562  1.690401  1.788337  1.822639 -0.349933 -0.141406  1.203124 -1.059868
# 46563 -0.617746 -0.520080 -0.592154  0.682652  1.086992  2.289138 -1.059868
#
#              14        15
# 0     -0.216814 -0.577099
# 1     -0.216814 -0.577099
# 2     -0.216814 -0.577099
# 3     -0.216814 -0.539735
# 4     -0.193143 -0.577099
# ...         ...       ...
# 46559 -0.216814  1.793987
# 46560  2.150311 -0.577099
# 46561  0.327624  1.709623
# 46562 -0.216814 -0.577099
# 46563  1.747899  1.261246
#
# [46564 rows x 16 columns]

# %%
X_train_1, X_test_1, y_train_1, y_test_1 = train_test_from_x_y(X_new_1,
                                                                     y_1,
                                                                     last_train_time_step=last_train_time_step,
                                                                     last_time_step=last_time_step)

# %%
sizes_1 = {
    "X Size": len(X_train_1) + len(X_test_1),
    "y Size": len(y_train_1) + len(y_test_1),
    "X_train Size": len(X_train_1),
    "X_test Size": len(X_test_1),
    "y_train Size": len(y_train_1),
    "y_test Size": len(y_test_1),
    "y_train Malicious Size": len(np.where(y_train_1 == 1)[0]),
    "y_train Bening Size": len(np.where(y_train_1 == 0)[0]),
    "y_test Malicious Size": len(np.where(y_test_1 == 1)[0]),
    "y_test Bening Size": len(np.where(y_test_1 == 0)[0]),
}

# %%
df_sizes = pd.DataFrame(data=sizes_1, index=[0])

# %%
df_sizes
# Out:
#    X Size  y Size  X_train Size  X_test Size  y_train Size  y_test Size  \
# 0   46564   46564         32594        13970         32594        13970
#
#    y_train Malicious Size  y_train Bening Size  y_test Malicious Size  \
# 0                    3181                29413                   1364
#
#    y_test Bening Size
# 0               12606

# %%
clf_1 = EnergyBasedFlowClassifier(n_bins=30, cutoff_quantile=0.9, pseudocounts=0.1)

# %%
clf_1.fit(X_train_1, y_train)
# Out:
# EnergyBasedFlowClassifier(cutoff_quantile=0.9, pseudocounts=0.1)

# %%
y_pred_1, y_energies_1 = clf.predict(X_test_1, return_energies=True)

# %%
# ploting energies
benign = np.where(y_test_1 == 0)[0]
malicious = np.where(y_test_1 == 1)[0]

benign_energies = y_energies_1[benign]
malicious_energies = y_energies_1[malicious]
cutoff = clf.estimators_[0].cutoff_

bins = np.histogram(y_energies, bins=60)[1]

plt.hist(
    malicious_energies,
    bins,
    facecolor="#006680",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="malicious",
)
plt.hist(
    benign_energies,
    bins,
    facecolor="#b3b3b3",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="benign",
)
plt.axvline(cutoff, color="r", linestyle="dashed", linewidth=1)
plt.legend()

plt.xlabel("Energy", fontsize=12)
plt.ylabel("Density", fontsize=12)
plt.savefig(f'{results_efc}/1_feature_selection_score_function_f_classif_k_16')

# %% [markdown]
# ##### EFC metrics

# %%
model_score_1 = calculate_model_score(y_true=y_test_1.values, y_pred=y_pred_1)

# %%
model_score_1
# Out:
# {'accuracy': 0.09756621331424481,
#  'f1': np.float64(0.01735867931398029),
#  'f1_micro': np.float64(0.09756621331424481),
#  'f1_macro': np.float64(0.08889323680949586),
#  'precision': np.float64(0.00952683191070441),
#  'recall': np.float64(0.09756621331424481)}

# %%
df_efc_metrics = pd.DataFrame(data=model_score_1, index=[0])

# %%
df_efc_metrics
# Out:
#    accuracy        f1  f1_micro  f1_macro  precision    recall
# 0  0.097566  0.017359  0.097566  0.088893   0.009527  0.097566

# %%
labels_cm = ["True Negative", "False positive", "False Negative", "True Positive"]

# %%
cm_1 = confusion_matrix(y_test_1, y_pred_1, labels=[1, 0])

# %%
cm_1 = np.reshape(cm_1, -1).tolist()

# %%
cm_1
# Out:
# [1363, 1, 12606, 0]

# %%
confusion_matrix_values_1 = {'Technique': 'feature selection score function f_classif k = 16'} | {label: val for val, label in zip(cm_1, labels_cm)}

# %%
confusion_matrix_values_1
# Out:
# {'Technique': 'feature selection score function f_classif k = 16',
#  'True Negative': 1363,
#  'False positive': 1,
#  'False Negative': 12606,
#  'True Positive': 0}

# %%
df_efc_confusion_matrix = pd.DataFrame(data=confusion_matrix_values_1,
                                       columns=["Technique", "True Negative", "False positive", "False Negative", "True Positive"],
                                       index=[0]
)

# %%
df_efc_confusion_matrix
# Out:
#                                            Technique  True Negative  \
# 0  feature selection score function f_classif k = 16           1363
#
#    False positive  False Negative  True Positive
# 0               1           12606              0

# %% [markdown]
# #### feature selection score function f_classif k = 16, removing aggregate columns from dataset

# %% [markdown]
# ##### removing aggregate columns from dataset
# recreating X and y from X_train, y_train, X_test, y_test

# %%
# Elliptic data set timestep
last_time_step = 49
last_train_time_step = 34
only_labeled = True

# %%
X_train_2, X_test_2, y_train_2, y_test_2 = run_elliptic_preprocessing_pipeline(
    last_train_time_step=last_train_time_step,
    last_time_step=last_time_step,
    only_labeled=only_labeled,
)
# Out:
# /var/folders/8b/c9dvlw851kx2vf3r7gc5gbbh0000gn/T/ipykernel_47895/3533226547.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_classes.replace({"class": {"1": 1, "2": 0, "unknown": 2}}, inplace=True)

# %%
X_train_2.drop(columns=[f"agg_feat_{i}" for i in range(72)], axis=1, inplace=True)

# %%
X_test_2.drop(columns=[f"agg_feat_{i}" for i in range(72)], axis=1, inplace=True)

# %%
y_train_2.drop(columns=[f"agg_feat_{i}" for i in range(72)], axis=1, inplace=True)

# %%
y_test_2.drop(columns=[f"agg_feat_{i}" for i in range(72)], axis=1, inplace=True)

# %%
sizes_2 = {
    "X Size": len(X_train_2) + len(X_test_2),
    "y Size": len(y_train_2) + len(y_test_2),
    "X_train Size": len(X_train_2),
    "X_test Size": len(X_test_2),
    "y_train Size": len(y_train_2),
    "y_test Size": len(y_test_2),
    "y_train Malicious Size": len(np.where(y_train_2 == 1)[0]),
    "y_train Bening Size": len(np.where(y_train_2 == 0)[0]),
    "y_test Malicious Size": len(np.where(y_test_2 == 1)[0]),
    "y_test Bening Size": len(np.where(y_test_2 == 0)[0]),
}

# %%
sizes_2
# Out:
# {'X Size': 46564,
#  'y Size': 46564,
#  'X_train Size': 29894,
#  'X_test Size': 16670,
#  'y_train Size': 29894,
#  'y_test Size': 16670,
#  'y_train Malicious Size': 3462,
#  'y_train Bening Size': 26432,
#  'y_test Malicious Size': 1083,
#  'y_test Bening Size': 15587}

# %%
df_sizes.loc[1] = sizes_2

# %%
df_sizes
# Out:
#    X Size  y Size  X_train Size  X_test Size  y_train Size  y_test Size  \
# 0   46564   46564         32594        13970         32594        13970
# 1   46564   46564         29894        16670         29894        16670
#
#    y_train Malicious Size  y_train Bening Size  y_test Malicious Size  \
# 0                    3181                29413                   1364
# 1                    3462                26432                   1083
#
#    y_test Bening Size
# 0               12606
# 1               15587

# %%
X_2, y_2 = train_test_from_splitted(X_train_2, y_train_2, X_test_2, y_test_2, return_df=False)

# %% [markdown]
# ##### feature selection with sklearn

# %%
X_2.shape
# Out:
# (46564, 94)

# %%
X_new_2 = SelectKBest(f_classif, k=16).fit_transform(X_2, y_2)

# %%
X_new_2.shape
# Out:
# (46564, 16)

# %%
X_new_2
# Out:
# array([[-0.41400813,  4.18119239,  4.34663973, ...,  0.81087855,
#         -0.6942352 ,  2.08465074],
#        [-0.27112413,  3.68552898,  3.63375331, ...,  0.81087855,
#         -0.6942352 ,  2.08465074],
#        [-0.41395175, -0.48829574, -0.23255262, ..., -0.71186099,
#         -0.63364772, -0.6762787 ],
#        ...,
#        [-0.41388414,  0.66986851,  1.77421454, ..., -0.76175378,
#         -0.69398672, -0.72077698],
#        [ 3.15409476,  2.47923489, -0.23255262, ...,  1.69040136,
#          1.78833698,  1.82263919],
#        [ 0.83152309,  0.68956737,  0.02127675, ..., -0.61774633,
#         -0.52007978, -0.59215426]])

# %%
X_train_2, X_test_2, y_train_2, y_test_2 = train_test_from_x_y(X_new_2,
                                                               y_2,
                                                               last_train_time_step=last_train_time_step,
                                                               last_time_step=last_time_step
)

# %% [markdown]
# ##### efc with feature selection

# %%
clf_2 = EnergyBasedFlowClassifier(n_bins=30, cutoff_quantile=0.9, pseudocounts=0.1)

# %%
clf_2.fit(X_train_2, y_train_2)
# Out:
# EnergyBasedFlowClassifier(cutoff_quantile=0.9, pseudocounts=0.1)

# %%
y_pred_2, y_energies_2 = clf.predict(X_test_2, return_energies=True)

# %%
# ploting energies
benign = np.where(y_test_2 == 0)[0]
malicious = np.where(y_test_2 == 1)[0]

benign_energies = y_energies_2[benign]
malicious_energies = y_energies_2[malicious]
cutoff = clf.estimators_[0].cutoff_

bins = np.histogram(y_energies, bins=60)[1]

plt.hist(
    malicious_energies,
    bins,
    facecolor="#006680",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="malicious",
)
plt.hist(
    benign_energies,
    bins,
    facecolor="#b3b3b3",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="benign",
)
plt.axvline(cutoff, color="r", linestyle="dashed", linewidth=1)
plt.legend()

plt.xlabel("Energy", fontsize=12)
plt.ylabel("Density", fontsize=12)
plt.savefig(f'{results_efc}/2_feature_selection_score_function_f_classif_k_16_no_aggregated_columns')

# %% [markdown]
# ##### EFC metrics

# %%
model_score_2 = calculate_model_score(y_true=y_test_2.values, y_pred=y_pred_2)

# %%
model_score_2
# Out:
# {'accuracy': 0.8632068718682891,
#  'f1': np.float64(0.8748124141102307),
#  'f1_micro': np.float64(0.8632068718682891),
#  'f1_macro': np.float64(0.679790731174645),
#  'precision': np.float64(0.8911021667586099),
#  'recall': np.float64(0.8632068718682891)}

# %%
df_efc_metrics.loc[1] = model_score_2

# %%
df_efc_metrics
# Out:
#    accuracy        f1  f1_micro  f1_macro  precision    recall
# 0  0.097566  0.017359  0.097566  0.088893   0.009527  0.097566
# 1  0.863207  0.874812  0.863207  0.679791   0.891102  0.863207

# %%
labels_cm = ["True Negative", "False positive", "False Negative", "True Positive"]

# %%
cm_2 = confusion_matrix(y_test_2, y_pred_2, labels=[1, 0])

# %%
cm_2 = np.reshape(cm_2, -1).tolist()

# %%
cm_2
# Out:
# [743, 621, 1290, 11316]

# %%
confusion_matrix_values_2 = {'Technique': 'feature selection score function f_classif k = 16 no aggregated columns'} | {label: val for val, label in zip(cm_2, labels_cm)}

# %%
confusion_matrix_values_2
# Out:
# {'Technique': 'feature selection score function f_classif k = 16 no aggregated columns',
#  'True Negative': 743,
#  'False positive': 621,
#  'False Negative': 1290,
#  'True Positive': 11316}

# %%
df_efc_confusion_matrix.loc[1] = confusion_matrix_values_2

# %%
df_efc_confusion_matrix
# Out:
#                                            Technique  True Negative  \
# 0  feature selection score function f_classif k = 16           1363
# 1  feature selection score function f_classif k =...            743
#
#    False positive  False Negative  True Positive
# 0               1           12606              0
# 1             621            1290          11316

# %% [markdown]
# ### PCA

# %% [markdown]
# #### Preprocess the Dataset
# The features are all on different scales. To bring them all to a common scale, we’ll use the StandardScaler that transforms the features to have zero mean and unit variance

# %%
from sklearn.preprocessing import StandardScaler

# %%
std_scaler = StandardScaler()
df_scaled = std_scaler.fit_transform(df)

# %%
df.head()
# Out:
#    time_step  trans_feat_0  trans_feat_1  trans_feat_2  trans_feat_3  \
# 0          1      0.163054      1.963790     -0.646376     12.409294
# 1          1     -0.005027      0.578941     -0.091383      4.380281
# 2          1     -0.147852     -0.184668     -1.201369     -0.121970
# 3          1     -0.151357     -0.184668     -1.201369     -0.121970
# 4          1     -0.172306     -0.184668     -1.201369      0.028105
#
#    trans_feat_4  trans_feat_5  trans_feat_6  trans_feat_7  trans_feat_8  ...  \
# 0     -0.063725      9.782742     12.414558     -0.163645     -0.115831  ...
# 1     -0.063725      4.667146      0.851305     -0.163645     -0.144554  ...
# 2     -0.043875     -0.113002     -0.061584     -0.137933     -0.144108  ...
# 3     -0.043875     -0.113002     -0.061584     -0.141519     -0.147643  ...
# 4     -0.043875     -0.029140      0.242712     -0.163640     -0.169115  ...
#
#    agg_feat_63  agg_feat_64  agg_feat_65  agg_feat_66  agg_feat_67  \
# 0    -0.613614     0.241128     0.241406     1.072793     0.085530
# 1    -0.613614     0.241128     0.241406     0.604120     0.008632
# 2    -0.613614     0.241128     0.241406     0.018279    -0.087490
# 3    -0.582077    -0.979074    -0.978556     0.018279    -0.087490
# 4    -0.600999     0.241128     0.241406     0.018279    -0.068266
#
#    agg_feat_68  agg_feat_69  agg_feat_70  agg_feat_71  class
# 0    -0.131155     0.677799    -0.120613    -0.119792      0
# 1    -0.131155     0.333211    -0.120613    -0.119792      0
# 2    -0.131155    -0.097524    -0.120613    -0.119792      0
# 3    -0.131155    -0.097524    -0.120613    -0.119792      0
# 4    -0.084674    -0.054450    -1.760926    -1.760984      0
#
# [5 rows x 167 columns]

# %%
df_scaled
# Out:
# array([[-1.55687812,  0.30702549,  1.16882093, ..., -0.08332004,
#         -0.08205159, -0.32888502],
#        [-1.55687812,  0.06777975,  0.27191143, ..., -0.08332004,
#         -0.08205159, -0.32888502],
#        [-1.55687812, -0.13551708, -0.22264614, ..., -0.08332004,
#         -0.08205159, -0.32888502],
#        ...,
#        [ 1.60978159, -0.16762877, -0.15366794, ..., -0.08332004,
#         -0.08205159,  3.04057635],
#        [ 1.60978159, -0.05848288, -0.17827679, ..., -0.08332004,
#         -0.08205159, -0.32888502],
#        [ 1.60978159, -0.16990809, -0.15367967, ..., -0.08332004,
#         -0.08205159,  3.04057635]])

# %% [markdown]
# #### Apply PCA on the Preprocessed Dataset
# The number of principal components is the number of dimensions that you’d like to reduce the feature space to

# %%
from sklearn.decomposition import PCA

# %%
n_components = 27
pca = PCA(n_components=n_components, svd_solver='full')
pca.fit_transform(df_scaled)
# Out:
# array([[ 0.34457844, -3.66413025,  3.56273776, ..., -1.86035372,
#         -2.24872767,  0.43341381],
#        [ 0.25562841, -3.65991645,  1.43792025, ...,  0.12289469,
#         -1.74936422, -0.13458222],
#        [-2.54949133, -4.56475411, -0.14570137, ...,  0.25691608,
#          0.16440279, -1.44230193],
#        ...,
#        [-3.90076907,  4.61310512,  0.22765369, ...,  2.01644977,
#          0.9404452 , -0.57569337],
#        [ 3.51386375,  5.29854655, -3.16517453, ..., -0.34978699,
#          0.86662784, -0.22292302],
#        [-2.16588448,  4.11045745, -0.18586454, ..., -0.78973606,
#          2.11328564, -0.43209535]])

# %% [markdown]
# #### Analyzing PCA Results

# %%
pca.components_
# Out:
# array([[-5.94748620e-02,  4.35736015e-02, -1.85747020e-02, ...,
#          2.47000473e-02,  2.48244205e-02, -3.99544248e-02],
#        [ 2.18369524e-01,  9.25356559e-02,  5.20501395e-02, ...,
#         -3.91630943e-04, -3.88506754e-04, -1.32744190e-02],
#        [-1.41559456e-03,  2.36154691e-01,  7.13917451e-02, ...,
#         -6.22668527e-03, -6.58300766e-03, -2.55833603e-02],
#        ...,
#        [-3.32004984e-02,  4.69364015e-03, -3.03230446e-02, ...,
#         -4.25789913e-02, -4.27774203e-02,  1.33925604e-02],
#        [ 3.84843560e-02,  3.49681846e-02, -3.29384366e-02, ...,
#         -1.87058662e-01, -1.86929396e-01,  1.58743369e-01],
#        [ 1.61890921e-02,  2.07125809e-02,  1.05809989e-03, ...,
#          5.34459561e-01,  5.35002103e-01,  2.82975591e-02]])

# %%
len(pca.components_)
# Out:
# 27

# %%
total_variance = sum(pca.explained_variance_ratio_)

# %%
print(f"Here, we see that {n_components} principal components capture over {total_variance * 100:.2f}% of total variance in the dataset")
# Out:
# Here, we see that 27 principal components capture over 73.73% of total variance in the dataset

# %% [markdown]
# #### EFC with PCA

# %%
pca.components_[0]
# Out:
# array([-0.05947486,  0.0435736 , -0.0185747 , -0.08170965, -0.01411799,
#         0.00059108, -0.01489151, -0.00048854,  0.04107678,  0.04329961,
#         0.0196294 ,  0.04380183, -0.06659124, -0.06530058,  0.00058809,
#         0.00295288,  0.01073383,  0.04286898,  0.04698863,  0.03903899,
#         0.02789617,  0.03015706,  0.1172012 ,  0.14270053,  0.09303158,
#         0.14455625,  0.00936936,  0.00935962,  0.1172016 ,  0.14269835,
#         0.09303184,  0.14455679,  0.00935879,  0.00934661,  0.02300544,
#         0.02402567,  0.01105319,  0.02374397,  0.01198995,  0.01204281,
#         0.125444  ,  0.1456681 ,  0.0753465 ,  0.13898652,  0.01861518,
#         0.02021099,  0.12546396,  0.14746614,  0.09185043,  0.13795919,
#         0.01759594,  0.01916348,  0.14263337,  0.14775607,  0.05743328,
#         0.16111398,  0.01224341,  0.01325424,  0.01188504,  0.15117803,
#         0.14908882,  0.14442089,  0.12249369,  0.12324873,  0.01186184,
#         0.15117791,  0.14908656,  0.14441731,  0.12249959,  0.12321875,
#         0.00881604,  0.01720818,  0.01149853,  0.01005944,  0.13801849,
#         0.13761025,  0.00466065,  0.15033667,  0.14825058,  0.14663359,
#         0.13661688,  0.13572648,  0.00410588,  0.15757819,  0.15609458,
#         0.1542077 ,  0.13683023,  0.13597325,  0.05314839,  0.16476456,
#         0.16540571,  0.16210804,  0.10706209,  0.10611344,  0.00833327,
#         0.01034553,  0.01769614,  0.01315815, -0.02389821, -0.02466772,
#        -0.05381141, -0.05911534, -0.00620383, -0.0580913 ,  0.01008353,
#         0.01009864, -0.03625188, -0.04417116, -0.02232014, -0.04052624,
#        -0.00686452, -0.00712653, -0.05971428, -0.0814657 , -0.01678002,
#        -0.07697562, -0.00711244, -0.00720422, -0.0091921 , -0.01854885,
#        -0.01047918, -0.01103879, -0.01090715, -0.01148724, -0.0034693 ,
#         0.00491254,  0.01604781,  0.00454596,  0.0145004 ,  0.01442245,
#         0.01047417,  0.03108692,  0.02952191,  0.02991075,  0.00506375,
#         0.00571142, -0.05576503, -0.05649011, -0.02427852, -0.05896309,
#        -0.02238777, -0.0229238 , -0.03530341, -0.00917481, -0.00943653,
#        -0.02239456, -0.0414091 , -0.04131406, -0.08328286, -0.04675575,
#         0.04170779, -0.07350432, -0.04719961, -0.04716236, -0.0344775 ,
#        -0.00024116,  0.01047924, -0.01211918, -0.04635953, -0.04672212,
#         0.00042037,  0.00225505, -0.00034   , -0.00393056,  0.02470005,
#         0.02482442, -0.03995442])

# %%
df_efc = pd.DataFrame(data=pca.components_)

# %%
df_efc
# Out:
#          0         1         2         3         4         5         6    \
# 0  -0.059475  0.043574 -0.018575 -0.081710 -0.014118  0.000591 -0.014892
# 1   0.218370  0.092536  0.052050  0.189668  0.007689  0.007793  0.008367
# 2  -0.001416  0.236155  0.071392  0.005955  0.062113  0.024422  0.060689
# 3   0.063046 -0.034408  0.035741  0.004033  0.021106  0.003918  0.022559
# 4  -0.082663  0.075888 -0.020094 -0.030766 -0.001264  0.004119 -0.002875
