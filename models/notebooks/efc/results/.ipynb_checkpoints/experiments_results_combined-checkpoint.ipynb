# %% [markdown]
# # Combining Experiments Results
# Combining metrics accuracy,f1,f1_micro,f1_macro,precision,recall from each experiment

# %%
import pandas as pd

# %%
experiment_2_metrics = pd.read_csv('experiment_2/df_efc_metrics.csv')

# %%
experiment_2_metrics
# Out:
#                                        Technique  accuracy        f1  \
# 0                            All labeled samples  0.907978  0.891453
# 1  All labeled samples Without Aggregate Columns  0.812837  0.840390
#
#    f1_micro  f1_macro  precision    recall
# 0  0.907978  0.487943   0.876073  0.907978
# 1  0.812837  0.465513   0.870596  0.812837

# %%
experiment_3_metrics = pd.read_csv('experiment_3/df_efc_metrics.csv')

# %%
experiment_3_metrics
# Out:
#                                         Technique  accuracy        f1  \
# 0                              Unbalanced Dataset  0.907978  0.891453
# 1  Balanced Dataset (Equally Distributed Classes)  0.675468  0.644026
# 2                                           Smote  0.908575  0.908352
# 3                             Random Oversampling  0.927594  0.906509
# 4                            Random Undersampling  0.867546  0.890289
#
#    f1_micro  f1_macro  precision    recall
# 0  0.907978  0.487943   0.876073  0.907978
# 1  0.675468  0.644065   0.771573  0.675468
# 2  0.908575  0.908352   0.912600  0.908575
# 3  0.927594  0.533104   0.894525  0.927594
# 4  0.867546  0.651955   0.925580  0.867546

# %%
experiment_4_metrics = pd.read_csv('experiment_4/df_efc_metrics_1.csv')

# %%
experiment_4_metrics
# Out:
#    accuracy        f1  f1_micro  f1_macro  precision    recall
# 0  0.864925  0.876671  0.864925  0.685565   0.893468  0.864925
# 1  0.846886  0.855821  0.846886  0.617228   0.866372  0.846886
# 2  0.829707  0.834196  0.829707  0.542463   0.838889  0.829707
# 3  0.810880  0.809623  0.810880  0.456244   0.808371  0.810880
# 4  0.811525  0.811432  0.811525  0.464670   0.811340  0.811525
# 5  0.821761  0.827481  0.821761  0.527015   0.833479  0.821761

# %%
experiment_5_metrics = pd.read_csv('experiment_5/df_efc_metrics.csv')

# %%
experiment_5_metrics
# Out:
#                            Technique  accuracy        f1  f1_micro  f1_macro  \
# 0  SMOTE With Feature Selection k=10  0.812351  0.811021  0.812351  0.811021
# 1  SMOTE With Feature Selection k=20  0.864787  0.864645  0.864787  0.864645
# 2  SMOTE With Feature Selection k=30  0.881168  0.881139  0.881168  0.881139
# 3  SMOTE With Feature Selection k=40  0.884737  0.884730  0.884737  0.884730
# 4  SMOTE With Feature Selection k=50  0.884539  0.884528  0.884539  0.884528
# 5  SMOTE With Feature Selection k=60  0.894733  0.894732  0.894733  0.894732
#
#    precision    recall
# 0   0.821398  0.812351
# 1   0.866318  0.864787
# 2   0.881533  0.881168
# 3   0.884832  0.884737
# 4   0.884684  0.884539
# 5   0.894737  0.894733
