# %% [markdown]
# # Experiment 1
# Multi-class EFC dry run

# %%
# solve the `ImportError: attempted relative import with no known parent package` error when making relative importings inside a jupyter notebook
import sys
import os

current_dir = os.path.dirname(os.path.abspath("__file__")) #this variable returns the current path
parent_dir = os.path.dirname(os.path.dirname(current_dir)) # this variable returns the path /efc/
sys.path.append(parent_dir)

# %%
from babd.experiment_1.experiment import main

# %% [markdown]
# ## Set Up
# BABD original dataset contains 13 labels, all of them are ilicit ones. We want to run EFC on this dataset and collect result metrics.

# %%
df_efc_sizes, df_efc_metrics, df_efc_confusion_matrix = main(
    technique="Multi-class EFC on BABD Dataset",
    fig_name="{technique}"
)
# Out:
# 2025-06-15 10:12:02.241 | INFO     | babd.experiment_1.experiment:main:25 - Initiating BABD dataset Experiment 1.
# 2025-06-15 10:12:07.479 | INFO     | babd.experiment_1.experiment:main:39 - Experiment params with technique Multi-class EFC on BABD Dataset
# /Users/kevinaraujo/.pyenv/versions/masters/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2025-06-15 10:34:22.134 | INFO     | babd.experiment_1.experiment:main:60 - Experiment results
# 2025-06-15 10:34:22.137 | SUCCESS  | babd.experiment_1.experiment:main:63 - Finished Experiment 4
# 2025-06-15 10:34:22.137 | INFO     | babd.experiment_1.experiment:main:66 - Saving experiments results to .csv to ./Multi-class EFC on BABD Dataset folder.
