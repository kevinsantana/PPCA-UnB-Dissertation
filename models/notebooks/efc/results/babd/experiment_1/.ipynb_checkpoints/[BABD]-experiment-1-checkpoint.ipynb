# %% [markdown]
# # Experiment 1
# Multi-class EFC dry run

# %%
# solve the `ImportError: attempted relative import with no known parent package` error when making relative importings inside a jupyter notebook
import sys
import os

current_dir = os.path.dirname(os.path.abspath("__file__")) #this variable returns the current path
parent_dir = os.path.dirname(os.path.dirname(current_dir)) # this variable returns the path /efc/
sys.path.append(parent_dir)

# %%
from babd.experiment_1.experiment import main

# %% [markdown]
# ## Set Up
# BABD original dataset contains 13 labels, all of them are ilicit ones. We want to run EFC on this dataset and collect result metrics.

# %%
df_efc_sizes, df_efc_metrics, df_efc_confusion_matrix = main(
    technique="Multi-class EFC on BABD Dataset",
    fig_name="{technique}"
)
# Out:
# 2025-06-15 10:07:01.243 | INFO     | babd.experiment_1.experiment:main:25 - Initiating BABD dataset Experiment 1.
# 2025-06-15 10:07:06.546 | ERROR    | babd.experiment_1.experiment:main:92 - Exception on experiment 1. Technique: Multi-class EFC on BABD Dataset. Exception: train_test_split() got an unexpected keyword argument 'random_state'
# Traceback (most recent call last):
#
#   File "/Users/kevinaraujo/.pyenv/versions/3.12.1/lib/python3.12/runpy.py", line 198, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#            │         │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#            │         └ <code object <module> at 0x10419a040, file "/Users/kevinaraujo/.pyenv/versions/masters/lib/python3.12/site-packages/ipykernel...
#            └ <function _run_code at 0x10421a0c0>
#   File "/Users/kevinaraujo/.pyenv/versions/3.12.1/lib/python3.12/runpy.py", line 88, in _run_code
#     exec(code, run_globals)
#          │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#          └ <code object <module> at 0x10419a040, file "/Users/kevinaraujo/.pyenv/versions/masters/lib/python3.12/site-packages/ipykernel...
#   File "/Users/kevinaraujo/.pyenv/versions/masters/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#     │   └ <bound method Application.launch_instance of <class 'ipykernel.kernelapp.IPKernelApp'>>
#     └ <module 'ipykernel.kernelapp' from '/Users/kevinaraujo/.pyenv/versions/masters/lib/python3.12/site-packages/ipykernel/kernela...
#   File "/Users/kevinaraujo/.pyenv/versions/masters/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#     │   └ <function IPKernelApp.start at 0x1078eb600>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x104233620>
#   File "/Users/kevinaraujo/.pyenv/versions/masters/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#     │    │       └ <function BaseAsyncIOLoop.start at 0x107928540>
#     │    └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x1079199a0>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x104233620>
#   File "/Users/kevinaraujo/.pyenv/versions/masters/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#     │    │            └ <function BaseEventLoop.run_forever at 0x10549cd60>
#     │    └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#     └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x1079199a0>
#   File "/Users/kevinaraujo/.pyenv/versions/3.12.1/lib/python3.12/asyncio/base_events.py", line 638, in run_forever
#     self._run_once()
#     │    └ <function BaseEventLoop._run_once at 0x10549eb60>
#     └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#   File "/Users/kevinaraujo/.pyenv/versions/3.12.1/lib/python3.12/asyncio/base_events.py", line 1971, in _run_once
#     handle._run()
#     │      └ <function Handle._run at 0x105426f20>
#     └ <Handle Task.task_wakeup(<Future finis...3B)>, ...],))>)>
#   File "/Users/kevinaraujo/.pyenv/versions/3.12.1/lib/python3.12/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#     │    │            │    │           │    └ <member '_args' of 'Handle' objects>
#     │    │            │    │           └ <Handle Task.task_wakeup(<Future finis...3B)>, ...],))>)>
#     │    │            │    └ <member '_callback' of 'Handle' objects>
#     │    │            └ <Handle Task.task_wakeup(<Future finis...3B)>, ...],))>)>
#     │    └ <member '_context' of 'Handle' objects>
#     └ <Handle Task.task_wakeup(<Future finis...3B)>, ...],))>)>
#   File "/Users/kevinaraujo/.pyenv/versions/masters/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#           │    └ <function Kernel.process_one at 0x10788b6a0>
#           └ <ipykernel.ipkernel.IPythonKernel object at 0x10791a9f0>
#   File "/Users/kevinaraujo/.pyenv/versions/masters/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#           │         └ ([<zmq.Frame(b'ee732a38-056'...36B)>, <zmq.Frame(b'<IDS|MSG>')>, <zmq.Frame(b'f877103dc130'...64B)>, <zmq.Frame(b'{"date":"20...
#           └ <bound method Kernel.dispatch_shell of <ipykernel.ipkernel.IPythonKernel object at 0x10791a9f0>>
#   File "/Users/kevinaraujo/.pyenv/versions/masters/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#           └ <coroutine object IPythonKernel.execute_request at 0x107f6aa40>
#   File "/Users/kevinaraujo/.pyenv/versions/masters/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#                                   │       │      └ {'header': {'date': datetime.datetime(2025, 6, 15, 13, 7, 1, 238000, tzinfo=tzutc()), 'msg_id': 'd07ad5af-b8dd-4e40-a962-0aef...
#                                   │       └ [b'ee732a38-056f-45f5-a48a-21b2658224cc']
#                                   └ <zmq.eventloop.zmqstream.ZMQStream object at 0x107919eb0>
#   File "/Users/kevinaraujo/.pyenv/versions/masters/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#                           └ <coroutine object IPythonKernel.do_execute at 0x1076ea8c0>
#   File "/Users/kevinaraujo/.pyenv/versions/masters/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#           │     └ <function ZMQInteractiveShell.run_cell at 0x1078c7380>
#           └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x1078cbaa0>
#   File "/Users/kevinaraujo/.pyenv/versions/masters/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#                              │       └ {'store_history': True, 'silent': False, 'cell_id': '6d0e5a53-fc87-49b6-bd3e-d5089f5cd623'}
#                              └ ('df_efc_sizes, df_efc_metrics, df_efc_confusion_matrix = main(\n    technique="Multi-class EFC on BABD Dataset",\n    fig_na...
#   File "/Users/kevinaraujo/.pyenv/versions/masters/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#              │    └ <function InteractiveShell._run_cell at 0x106aaa660>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x1078cbaa0>
#   File "/Users/kevinaraujo/.pyenv/versions/masters/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#              │      └ <coroutine object InteractiveShell.run_cell_async at 0x107873880>
#              └ <function _pseudo_sync_runner at 0x106a95800>
#   File "/Users/kevinaraujo/.pyenv/versions/masters/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#     │    └ <method 'send' of 'coroutine' objects>
#     └ <coroutine object InteractiveShell.run_cell_async at 0x107873880>
#   File "/Users/kevinaraujo/.pyenv/versions/masters/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                        │    │             │        │     └ '/var/folders/8b/c9dvlw851kx2vf3r7gc5gbbh0000gn/T/ipykernel_32776/3340640083.py'
#                        │    │             │        └ [<ast.Assign object at 0x12b7f6090>]
#                        │    │             └ <ast.Module object at 0x12b62b590>
#                        │    └ <function InteractiveShell.run_ast_nodes at 0x106aaa980>
#                        └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x1078cbaa0>
#   File "/Users/kevinaraujo/.pyenv/versions/masters/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#              │    │        │     │              └ False
#              │    │        │     └ <ExecutionResult object at 12b741700, execution_count=5 error_before_exec=None error_in_exec=None info=<ExecutionInfo object ...
#              │    │        └ <code object <module> at 0x12b7c6a30, file "/var/folders/8b/c9dvlw851kx2vf3r7gc5gbbh0000gn/T/ipykernel_32776/3340640083.py", ...
#              │    └ <function InteractiveShell.run_code at 0x106aaaa20>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x1078cbaa0>
#   File "/Users/kevinaraujo/.pyenv/versions/masters/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#          │         │    │               │    └ {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, ...
#          │         │    │               └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x1078cbaa0>
#          │         │    └ <property object at 0x106a8a070>
#          │         └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x1078cbaa0>
#          └ <code object <module> at 0x12b7c6a30, file "/var/folders/8b/c9dvlw851kx2vf3r7gc5gbbh0000gn/T/ipykernel_32776/3340640083.py", ...
#
#   File "/var/folders/8b/c9dvlw851kx2vf3r7gc5gbbh0000gn/T/ipykernel_32776/3340640083.py", line 1, in <module>
#     df_efc_sizes, df_efc_metrics, df_efc_confusion_matrix = main(
#                                                             └ <function main at 0x107ff0b80>
#
# > File "/Users/kevinaraujo/repos/dissertation/PPCA-UnB-Dissertation/models/notebooks/efc/results/babd/experiment_1/experiment.py", line 27, in main
#     X_train, X_test, y_train, y_test = run_babd_preprocessing_pipeline()
#                                        └ <function run_babd_preprocessing_pipeline at 0x11ca919e0>
#
#   File "/Users/kevinaraujo/repos/dissertation/PPCA-UnB-Dissertation/models/notebooks/efc/results/babd/common/format_dataset.py", line 34, in run_babd_preprocessing_pipeline
#     X_train_df, X_test_df, y_train, y_test = train_test_split(X, y)
#                                              │                │  └ 0          0
#                                              │                │    1          0
#                                              │                │    2          0
#                                              │                │    3          0
#                                              │                │    4          0
#                                              │                │              ..
#                                              │                │    544457    12
#                                              │                │    544458    12
#                                              │                │    544459    12
#                                              │                │    544460  ...
#                                              │                └                                         addaccount  SW   PAIa11-1   PAIa11-2  \
#                                              │                  0               13AM4VW2dhxYgXeQepoHkHSQuy6Ng...
#                                              └ <function train_test_split at 0x129a5fba0>
#
#   File "/Users/kevinaraujo/repos/dissertation/PPCA-UnB-Dissertation/models/notebooks/efc/results/babd/common/format_dataset.py", line 58, in train_test_split
#     X_train, X_test, y_train, y_test = train_test_split(
#                                        └ <function train_test_split at 0x129a5fba0>
#
# TypeError: train_test_split() got an unexpected keyword argument 'random_state'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_efc_sizes, df_efc_metrics, df_efc_confusion_matrix = main(
#       2     technique="Multi-class EFC on BABD Dataset",
#       3     fig_name="{technique}"
#       4 )
#
# TypeError: cannot unpack non-iterable NoneType object
