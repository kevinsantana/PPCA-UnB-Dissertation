# %% [markdown]
# ### Bitcoin blockchain in the presence of label scarcity

# %%
import pandas as pd

# %%
# %run research-aml-elliptic/src/experiments/supervised_baseline.py

# %%
data = pd.read_csv('research-aml-elliptic/output/supervised_avg_f1_per_model_over_5_runs.csv')
print(data)
# Out:
#                XGBoost  0.8026652998462327
# 0        Random Forest            0.824908
# 1  Logistic Regression            0.446908

# %%
# %run research-aml-elliptic/src/experiments/anomaly_detection_benchmark.py
# Out:
# Root directory:  /Users/kevinaraujo/repos/dissertation/PPCA-UnB-Dissertation/models/notebooks/research-aml-elliptic
# Starting model  PCA
# Starting model  LOF
# Starting model  CBLOF
# Starting model  IF
# Starting model  KNN
# Starting model  ABOD
# Starting model  OCSVM

# %%
data = pd.read_csv('research-aml-elliptic/output/table_2_illicit_f1_per_contamination_level.csv')
print(data)
# Out:
#            model  0.05   0.1  0.15   0.2
# 0           ABOD  0.07  0.07  0.07  0.07
# 1          CBLOF  0.01  0.01  0.03  0.04
# 2             IF  0.00  0.00  0.00  0.01
# 3            KNN  0.03  0.04  0.05  0.06
# 4            LOF  0.11  0.15  0.19  0.18
# 5          OCSVM  0.01  0.03  0.03  0.04
# 6            PCA  0.01  0.01  0.02  0.02
# 7  Random Forest  0.81  0.59  0.46  0.38

# %%
# %run research-aml-elliptic/src/experiments/umap_data_exploration.py
# Out:
# Root directory:  /Users/kevinaraujo/repos/dissertation/PPCA-UnB-Dissertation/models/notebooks/research-aml-elliptic
