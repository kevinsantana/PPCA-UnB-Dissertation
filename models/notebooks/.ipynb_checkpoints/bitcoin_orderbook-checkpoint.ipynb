# %% [markdown]
# ## Data Acquisition

# %%
import time
from collections import deque
from datetime import date, timedelta, datetime
from concurrent.futures import ThreadPoolExecutor

import requests
from loguru import logger

import pandas as pd

# %%
api_v4_trades = "https://api.mercadobitcoin.net/api/v4/{symbol}/orderbook"

# %%
 # fetch most recent trades
response_orderbook = requests.get(url=api_v4_trades.format(symbol="BTC-BRL"))

if response_orderbook.status_code != 200:
    logger.error(f"Error to fetch orderbook data: {response_orderbook.text}")

response_json = response_trades.json()

orderbook = [{"price": data[0], "volume": data[1], "type": "sell"}  for data in response_json["asks"]]
orderbook.extend([{"price": data[0], "volume": data[1], "type": "buy"}  for data in response_json["bids"]])

# %%
print(*orderbook)
# Out:
# {'price': '206788.33999994', 'volume': '0.04163157', 'type': 'sell'} {'price': '206791.66999994', 'volume': '0.06947163', 'type': 'sell'} {'price': '206795.00000000', 'volume': '0.05300811', 'type': 'sell'} {'price': '206813.00000000', 'volume': '0.32800000', 'type': 'sell'} {'price': '206838.00000000', 'volume': '0.32800000', 'type': 'sell'} {'price': '206940.98981234', 'volume': '0.03389000', 'type': 'sell'} {'price': '206940.99000000', 'volume': '0.00011859', 'type': 'sell'} {'price': '207035.00000000', 'volume': '0.49900000', 'type': 'sell'} {'price': '207963.57827532', 'volume': '0.80793892', 'type': 'sell'} {'price': '207963.58520705', 'volume': '0.05965000', 'type': 'sell'} {'price': '207975.00000000', 'volume': '1.66800000', 'type': 'sell'} {'price': '208024.98239000', 'volume': '0.24896735', 'type': 'sell'} {'price': '208598.69000000', 'volume': '0.00100000', 'type': 'sell'} {'price': '209239.99994000', 'volume': '0.30300000', 'type': 'sell'} {'price': '209240.00000000', 'volume': '1.01200000', 'type': 'sell'} {'price': '210000.00000000', 'volume': '0.00022902', 'type': 'sell'} {'price': '210599.90000000', 'volume': '0.04075849', 'type': 'sell'} {'price': '210615.91000000', 'volume': '0.00590244', 'type': 'sell'} {'price': '210690.00000000', 'volume': '0.68700000', 'type': 'sell'} {'price': '211600.00000000', 'volume': '0.01616567', 'type': 'sell'} {'price': '212200.00000000', 'volume': '0.38804378', 'type': 'sell'} {'price': '212999.00000000', 'volume': '0.00001042', 'type': 'sell'} {'price': '213000.00000000', 'volume': '0.04608189', 'type': 'sell'} {'price': '213200.00000000', 'volume': '0.13316087', 'type': 'sell'} {'price': '213964.00000000', 'volume': '0.32800000', 'type': 'sell'} {'price': '214000.00000000', 'volume': '0.00950662', 'type': 'sell'} {'price': '214500.00000000', 'volume': '0.10000000', 'type': 'sell'} {'price': '214899.91000000', 'volume': '0.00100000', 'type': 'sell'} {'price': '214900.00000000', 'volume': '1.05938741', 'type': 'sell'} {'price': '214997.00000000', 'volume': '0.25806702', 'type': 'sell'} {'price': '215000.00000000', 'volume': '0.06573937', 'type': 'sell'} {'price': '215034.45000000', 'volume': '0.00096026', 'type': 'sell'} {'price': '215067.00000000', 'volume': '0.00001042', 'type': 'sell'} {'price': '215154.45636000', 'volume': '0.00002937', 'type': 'sell'} {'price': '215656.00000000', 'volume': '0.00010000', 'type': 'sell'} {'price': '216000.00000000', 'volume': '0.14690797', 'type': 'sell'} {'price': '216372.00000000', 'volume': '0.00001026', 'type': 'sell'} {'price': '216506.00000000', 'volume': '0.00002050', 'type': 'sell'} {'price': '217000.00000000', 'volume': '0.00236873', 'type': 'sell'} {'price': '217019.53564000', 'volume': '0.00851555', 'type': 'sell'} {'price': '217019.61849000', 'volume': '0.00011802', 'type': 'sell'} {'price': '217135.00000000', 'volume': '0.00001042', 'type': 'sell'} {'price': '217500.00000000', 'volume': '0.09673840', 'type': 'sell'} {'price': '218000.00000000', 'volume': '0.20363503', 'type': 'sell'} {'price': '218014.93000000', 'volume': '0.10507572', 'type': 'sell'} {'price': '218200.00000000', 'volume': '0.01192775', 'type': 'sell'} {'price': '218299.00000000', 'volume': '0.00400000', 'type': 'sell'} {'price': '218361.21000000', 'volume': '0.03133000', 'type': 'sell'} {'price': '218472.00000000', 'volume': '0.00001026', 'type': 'sell'} {'price': '218608.00000000', 'volume': '0.00002050', 'type': 'sell'} {'price': '218800.00000000', 'volume': '0.01098350', 'type': 'sell'} {'price': '218906.00000000', 'volume': '0.00604326', 'type': 'sell'} {'price': '219000.00000000', 'volume': '0.02304096', 'type': 'sell'} {'price': '219000.11000000', 'volume': '0.00003523', 'type': 'sell'} {'price': '219200.00000000', 'volume': '0.00060000', 'type': 'sell'} {'price': '219203.00000000', 'volume': '0.00001042', 'type': 'sell'} {'price': '219254.11000000', 'volume': '0.00100000', 'type': 'sell'} {'price': '219300.00000000', 'volume': '0.00045794', 'type': 'sell' ...

# %%
btc_orderbook_df = pd.DataFrame.from_dict(orderbook, orient='columns')

# %%
btc_orderbook_df.head()
# Out:
#              price      volume  type
# 0  206788.33999994  0.04163157  sell
# 1  206791.66999994  0.06947163  sell
# 2  206795.00000000  0.05300811  sell
# 3  206813.00000000  0.32800000  sell
# 4  206838.00000000  0.32800000  sell

# %%
btc_orderbook_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   price   2000 non-null   object
#  1   volume  2000 non-null   object
#  2   type    2000 non-null   object
# dtypes: object(3)
# memory usage: 47.0+ KB

# %%
btc_orderbook_df["price"] = pd.to_numeric(btc_orderbook_df["price"])
btc_orderbook_df["volume"] = pd.to_numeric(btc_orderbook_df["volume"])

# %%
btc_orderbook_df.drop_duplicates()
# Out:
#           price    volume  type
# 0     206788.34  0.041632  sell
# 1     206791.67  0.069472  sell
# 2     206795.00  0.053008  sell
# 3     206813.00  0.328000  sell
# 4     206838.00  0.328000  sell
# ...         ...       ...   ...
# 1995   19350.00  0.000022   buy
# 1996   18159.61  0.000910   buy
# 1997   18000.00  0.010599   buy
# 1998   17860.01  0.029964   buy
# 1999   17860.00  0.000022   buy
#
# [2000 rows x 3 columns]

# %%
btc_orderbook_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   price   2000 non-null   float64
#  1   volume  2000 non-null   float64
#  2   type    2000 non-null   object
# dtypes: float64(2), object(1)
# memory usage: 47.0+ KB

# %%
btc_orderbook_df.to_csv("btc_orderbook_df.csv", sep='\t', index=False)
btc_orderbook_df.to_parquet("btc_orderbook_df.parquet", engine="fastparquet")

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from pycaret.clustering import *
mpl.rcParams['figure.dpi'] = 300

# %%
btc_orderbook_df.hist(bins = 30, figsize = (12,10), grid = False)
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(btc_orderbook_df.corr().round(decimals=2), annot=True)
plt.show()

# %%
btc_orderbook_df.columns[:2]
# Out:
# Index(['price', 'volume'], dtype='object')

# %%
plot_kws = {'scatter_kws': {'s': 2}, 'line_kws': {'color': 'red'}}
sns.pairplot(btc_orderbook_df, kind='reg', vars=btc_orderbook_df.columns[:2], plot_kws=plot_kws)
plt.show()

# %% [markdown]
# ## Model

# %%
cluster = setup(btc_orderbook_df, session_id=7652, index=False, normalize=True, ignore_features=["type"], use_gpu=True)
# Out:
# <style type="text/css">
# #T_6facd_row5_col1, #T_6facd_row9_col1, #T_6facd_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6facd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6facd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6facd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6facd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6facd_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6facd_row0_col1" class="data row0 col1" >7652</td>
#     </tr>
#     <tr>
#       <th id="T_6facd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6facd_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_6facd_row1_col1" class="data row1 col1" >(2000, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_6facd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6facd_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_6facd_row2_col1" class="data row2 col1" >(2000, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_6facd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6facd_row3_col0" class="data row3 col0" >Ignore features</td>
#       <td id="T_6facd_row3_col1" class="data row3 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6facd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6facd_row4_col0" class="data row4 col0" >Numeric features</td>
#       <td id="T_6facd_row4_col1" class="data row4 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_6facd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6facd_row5_col0" class="data row5 col0" >Preprocess</td>
#       <td id="T_6facd_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6facd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6facd_row6_col0" class="data row6 col0" >Imputation type</td>
#       <td id="T_6facd_row6_col1" class="data row6 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_6facd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6facd_row7_col0" class="data row7 col0" >Numeric imputation</td>
#       <td id="T_6facd_row7_col1" class="data row7 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_6facd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6facd_row8_col0" class="data row8 col0" >Categorical imputation</td>
#       <td id="T_6facd_row8_col1" class="data row8 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_6facd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6facd_row9_col0" class="data row9 col0" >Normalize</td>
#       <td id="T_6facd_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6facd_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6facd_row10_col0" class="data row10 col0" >Normalize method</td>
#       <td id="T_6facd_row10_col1" class="data row10 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_6facd_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6facd_row11_col0" class="data row11 col0" >CPU Jobs</td>
#       <td id="T_6facd_row11_col1" class="data row11 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_6facd_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6facd_row12_col0" class="data row12 col0" >Use GPU</td>
#       <td id="T_6facd_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6facd_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6facd_row13_col0" class="data row13 col0" >Log Experiment</td>
#       <td id="T_6facd_row13_col1" class="data row13 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6facd_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6facd_row14_col0" class="data row14 col0" >Experiment Name</td>
#       <td id="T_6facd_row14_col1" class="data row14 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_6facd_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6facd_row15_col0" class="data row15 col0" >USI</td>
#       <td id="T_6facd_row15_col1" class="data row15 col1" >9b8e</td>
#     </tr>
#   </tbody>
# </table>

# %%
kmeans = create_model('kmeans')
# Out:
# <style type="text/css">
# </style>
# <table id="T_3fc89">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3fc89_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3fc89_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3fc89_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3fc89_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3fc89_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3fc89_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3fc89_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3fc89_row0_col0" class="data row0 col0" >0.5695</td>
#       <td id="T_3fc89_row0_col1" class="data row0 col1" >2727.1085</td>
#       <td id="T_3fc89_row0_col2" class="data row0 col2" >0.5675</td>
#       <td id="T_3fc89_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_3fc89_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_3fc89_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
evaluate_model(kmeans)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
print(kmeans)
# Out:
# KMeans(n_clusters=4, random_state=7652)

# %%
plot_model(kmeans, 'elbow')

# %%
plot_model(kmeans)

# %%
plot_model(kmeans, plot='silhouette')

# %%
plot_model(kmeans, plot='distribution', save=True)
# Out:
# 'Distribution Plot.png'

# %%
models()
# Out:
#                                        Name  \
# ID
# kmeans                   K-Means Clustering
# ap                     Affinity Propagation
# meanshift             Mean Shift Clustering
# sc                      Spectral Clustering
# hclust             Agglomerative Clustering
# dbscan     Density-Based Spatial Clustering
# optics                    OPTICS Clustering
# birch                      Birch Clustering
#
#                                                    Reference
# ID
# kmeans                        sklearn.cluster._kmeans.KMeans
# ap         sklearn.cluster._affinity_propagation.Affinity...
# meanshift              sklearn.cluster._mean_shift.MeanShift
# sc              sklearn.cluster._spectral.SpectralClustering
# hclust     sklearn.cluster._agglomerative.AgglomerativeCl...
# dbscan                        sklearn.cluster._dbscan.DBSCAN
# optics                        sklearn.cluster._optics.OPTICS
# birch                           sklearn.cluster._birch.Birch

# %%
model = create_model('dbscan', num_clusters=4)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0bb98">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0bb98_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0bb98_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0bb98_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0bb98_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0bb98_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0bb98_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0bb98_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0bb98_row0_col0" class="data row0 col0" >0.7914</td>
#       <td id="T_0bb98_row0_col1" class="data row0 col1" >552.9455</td>
#       <td id="T_0bb98_row0_col2" class="data row0 col2" >4.0825</td>
#       <td id="T_0bb98_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_0bb98_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_0bb98_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(model)
# Out:
# DBSCAN(n_jobs=-1)

# %%
plot_model(model)

# %%
plot_model(model, plot='distribution')
