# %% [markdown]
# ## EFC-Package

# %%
from math import ceil
from pprint import pprint

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import auc, classification_report, confusion_matrix, f1_score, roc_curve

# %%
from efc import EnergyBasedFlowClassifier

# %%
from research_aml_elliptic.src.reaml.model_performance import calculate_model_score
from research_aml_elliptic.src.experiments.general_functions.elliptic_data_preprocessing import run_elliptic_preprocessing_pipeline

# %%
from sklearn.metrics import (
    f1_score,
    accuracy_score,
    precision_score,
    recall_score,
    roc_auc_score,
)
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, StratifiedKFold

# %%
from matplotlib import pyplot as plt

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.metrics import confusion_matrix, recall_score, precision_score, f1_score, accuracy_score

# %%
import seaborn as sns

# %%
# Import Elliptic data set and set variables
last_time_step = 49
last_train_time_step = 34
only_labeled = True

# %%
results_efc = 'results/efc'

# %% [markdown]
# ### Unsupervised Elliptic Data Set With EFC

# %%
# '1': 1, -> class1 (illicit)
# '2': 0, -> class2 (licit)
# 'unknown': 2 -> dropped
X_train, X_test, y_train, y_test = run_elliptic_preprocessing_pipeline(last_train_time_step=last_train_time_step,
                                                                             last_time_step=last_time_step,
                                                                             only_labeled=only_labeled)
# Out:
# /Users/kevinaraujo/repos/dissertation/PPCA-UnB-Dissertation/models/notebooks/research_aml_elliptic/src/experiments/general_functions/elliptic_data_preprocessing.py:46: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_classes.replace({"class": {"1": 1, "2": 0, "unknown": 2}}, inplace=True)

# %%
# X_test.drop(['time_step'], axis=1)

# %%
# X_train.drop(['time_step'], axis=1)

# %%
len(y_train) + len(y_test)
# Out:
# 46564

# %%
len(np.where(y_train == 1)[0]) + len(np.where(y_test == 1)[0])
# Out:
# 4545

# %%
len(np.where(y_train == 0)[0]) + len(np.where(y_test == 0)[0])
# Out:
# 42019

# %%
len(np.where(y_train == 2)[0]) + len(np.where(y_test == 2)[0])
# Out:
# 0

# %%
clf = EnergyBasedFlowClassifier(n_bins=30, cutoff_quantile=0.9)

# %%
clf.fit(X_train, y_train, base_class=0)
# Out:
# EnergyBasedFlowClassifier(cutoff_quantile=0.9)

# %%
y_pred, y_energies = clf.predict(X_test, return_energies=True)

# %%
# ploting energies
benign = np.where(y_test == 0)[0]
malicious = np.where(y_test == 1)[0]

benign_energies = y_energies[benign]
malicious_energies = y_energies[malicious]
cutoff = clf.estimators_[0].cutoff_

bins = np.histogram(y_energies, bins=60)[1]

plt.hist(
    malicious_energies,
    bins,
    facecolor="#006680",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="malicious",
)
plt.hist(
    benign_energies,
    bins,
    facecolor="#b3b3b3",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="benign",
)
plt.axvline(cutoff, color="r", linestyle="dashed", linewidth=1)
plt.legend()

plt.xlabel("Energy", fontsize=12)
plt.ylabel("Density", fontsize=12)
plt.savefig(f'{results_efc}/1_unsupervised_efc.png')

# %%
columns_metrics = ["accuracy", "f1", "f1_micro", "f1_macro", "precision", "recall", "roc_auc"]

# %%
metric_dict = {
    "accuracy": accuracy_score(y_test, y_pred),
    "f1": f1_score(y_test, y_pred, pos_label=1),
    "f1_micro": f1_score(y_test, y_pred, average="micro"),
    "f1_macro": f1_score(y_test, y_pred, average="macro"),
    "precision": precision_score(y_test, y_pred),
    "recall": recall_score(y_test, y_pred),
    "roc_auc": roc_auc_score(y_test, y_pred),
}

# %%
pprint(metric_dict)
# Out:
# {'accuracy': 0.8428914217156569,
#  'f1': np.float64(0.0030452988199467074),
#  'f1_macro': np.float64(0.4588859808982682),
#  'f1_micro': np.float64(0.8428914217156569),
#  'precision': np.float64(0.0025906735751295338),
#  'recall': np.float64(0.003693444136657433),
#  'roc_auc': np.float64(0.4524465809250683)}

# %%
df_efc_metrics = pd.DataFrame(data=metric_dict, columns=columns_metrics, index=[0])
df_efc_metrics.insert(0, 'Technique', 'Unbalanced Dataset')
df_efc_metrics
# Out:
#             Technique  accuracy        f1  f1_micro  f1_macro  precision  \
# 0  Unbalanced Dataset  0.842891  0.003045  0.842891  0.458886   0.002591
#
#      recall   roc_auc
# 0  0.003693  0.452447

# %% [markdown]
# ### Including Unlabeled Data

# %%
# Import Elliptic data set and set variables
last_time_step = 49
last_train_time_step = 34
only_labeled = False

# %%
# '1': 1, -> class1 (illicit)
# '2': 0, -> class2 (licit)
# 'unknown': 2 -> dropped
X_train, X_test, y_train, y_test = run_elliptic_preprocessing_pipeline(last_train_time_step=last_train_time_step,
                                                                             last_time_step=last_time_step,
                                                                             only_labeled=only_labeled)
# Out:
# /Users/kevinaraujo/repos/dissertation/PPCA-UnB-Dissertation/models/notebooks/research_aml_elliptic/src/experiments/general_functions/elliptic_data_preprocessing.py:46: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_classes.replace({"class": {"1": 1, "2": 0, "unknown": 2}}, inplace=True)

# %%
# X_test.drop(['time_step'], axis=1)

# %%
# X_train.drop(['time_step'], axis=1)

# %%
clf = EnergyBasedFlowClassifier(n_bins=30, cutoff_quantile=0.9)

# %%
clf.fit(X_train, y_train, base_class=0)
# Out:
# EnergyBasedFlowClassifier(cutoff_quantile=0.9)

# %%
y_pred, y_energies = clf.predict(X_test, return_energies=True)

# %%
y_test
# Out:
# 136265    2
# 136266    2
# 136267    2
# 136268    2
# 136269    2
#          ..
# 203764    2
# 203765    2
# 203766    1
# 203767    2
# 203768    2
# Name: class, Length: 67504, dtype: int64

# %%
# ploting energies
benign = np.where(y_test == 0)[0]
malicious = np.where(y_test == 1)[0]

benign_energies = y_energies[benign]
malicious_energies = y_energies[malicious]
cutoff = clf.estimators_[0].cutoff_

bins = np.histogram(y_energies, bins=60)[1]

plt.hist(
    malicious_energies,
    bins,
    facecolor="#006680",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="malicious",
)
plt.hist(
    benign_energies,
    bins,
    facecolor="#b3b3b3",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="benign",
)
plt.axvline(cutoff, color="r", linestyle="dashed", linewidth=1)
plt.legend()

plt.xlabel("Energy", fontsize=12)
plt.ylabel("Density", fontsize=12)

plt.savefig(f'{results_efc}/2_unlabeled_data.png')

# %%
metric_dict_1 = {
    "Technique": "Unlabeled Dataset",
    "accuracy": accuracy_score(y_test, y_pred),
    "f1": None,
    "f1_micro": f1_score(y_test, y_pred, average="micro"),
    "f1_macro": f1_score(y_test, y_pred, average="macro"),
    "precision": None,
    "recall": None,
    "roc_auc": None,
}

# %%
pprint(metric_dict_1)
# Out:
# {'Technique': 'Unlabeled Dataset',
#  'accuracy': 0.2600438492533776,
#  'f1': None,
#  'f1_macro': np.float64(0.16956057242421504),
#  'f1_micro': np.float64(0.2600438492533776),
#  'precision': None,
#  'recall': None,
#  'roc_auc': None}

# %%
df_efc_metrics.loc[1] = metric_dict_1
df_efc_metrics
# Out:
# /var/folders/8b/c9dvlw851kx2vf3r7gc5gbbh0000gn/T/ipykernel_99167/3028362540.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_efc_metrics.loc[1] = metric_dict_1
#             Technique  accuracy        f1  f1_micro  f1_macro  precision  \
# 0  Unbalanced Dataset  0.842891  0.003045  0.842891  0.458886   0.002591
# 1   Unlabeled Dataset  0.260044       NaN  0.260044  0.169561        NaN
#
#      recall   roc_auc
# 0  0.003693  0.452447
# 1       NaN       NaN

# %% [markdown]
# ### Removing Unlabeled Data

# %%
# Import Elliptic data set and set variables
last_time_step = 49
last_train_time_step = 34
only_labeled = True

# %%
# '1': 1, -> class1 (illicit)
# '2': 0, -> class2 (licit)
# 'unknown': 2 -> dropped
X_train, X_test, y_train, y_test = run_elliptic_preprocessing_pipeline(last_train_time_step=last_train_time_step,
                                                                             last_time_step=last_time_step,
                                                                             only_labeled=only_labeled)
# Out:
# /Users/kevinaraujo/repos/dissertation/PPCA-UnB-Dissertation/models/notebooks/research_aml_elliptic/src/experiments/general_functions/elliptic_data_preprocessing.py:46: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_classes.replace({"class": {"1": 1, "2": 0, "unknown": 2}}, inplace=True)

# %%
# X_test.drop(['time_step'], axis=1)

# %%
# X_train.drop(['time_step'], axis=1)

# %%
# find unlabeled samples indexes in the training set
idx_abnormal = np.where(y_train == 2)[0]

# %%
X_train.drop(idx_abnormal, axis=0, inplace=True)

# %%
y_train.drop(idx_abnormal, axis=0, inplace=True)

# %%
len(X_train), len(y_train)
# Out:
# (29894, 29894)

# %%
clf = EnergyBasedFlowClassifier(n_bins=30, cutoff_quantile=0.9)

# %%
clf.fit(X_train, y_train, base_class=0)
# Out:
# EnergyBasedFlowClassifier(cutoff_quantile=0.9)

# %%
y_pred, y_energies = clf.predict(X_test, return_energies=True)

# %%
# ploting energies
benign = np.where(y_test == 0)[0]
malicious = np.where(y_test == 1)[0]

benign_energies = y_energies[benign]
malicious_energies = y_energies[malicious]
cutoff = clf.estimators_[0].cutoff_

bins = np.histogram(y_energies, bins=60)[1]

plt.hist(
    malicious_energies,
    bins,
    facecolor="#006680",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="malicious",
)
plt.hist(
    benign_energies,
    bins,
    facecolor="#b3b3b3",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="benign",
)
plt.axvline(cutoff, color="r", linestyle="dashed", linewidth=1)
plt.legend()

plt.xlabel("Energy", fontsize=12)
plt.ylabel("Density", fontsize=12)

plt.savefig(f'{results_efc}/3_no_unlabeled_data.png')

# %%
metric_dict_2 = {
    "Technique": "No Unlabeled Data",
    "accuracy": accuracy_score(y_test, y_pred[:16670]),
    "f1": None,
    "f1_micro": f1_score(y_test, y_pred[:16670], average="micro"),
    "f1_macro": f1_score(y_test, y_pred[:16670], average="macro"),
    "precision": None,
    "recall": None,
    "roc_auc": None,
}

# %%
df_efc_metrics.loc[2] = metric_dict_2
df_efc_metrics
# Out:
# /var/folders/8b/c9dvlw851kx2vf3r7gc5gbbh0000gn/T/ipykernel_99167/1469362065.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_efc_metrics.loc[2] = metric_dict_2
#             Technique  accuracy        f1  f1_micro  f1_macro  precision  \
# 0  Unbalanced Dataset  0.842891  0.003045  0.842891  0.458886   0.002591
# 1   Unlabeled Dataset  0.260044       NaN  0.260044  0.169561        NaN
# 2   No Unlabeled Data  0.909238       NaN  0.909238  0.318326        NaN
#
#      recall   roc_auc
# 0  0.003693  0.452447
# 1       NaN       NaN
# 2       NaN       NaN

# %%
# '1': 1, -> class1 (illicit)
# '2': 0, -> class2 (licit)
# 'unknown': 2 -> dropped
X_train_1, X_test_1, y_train_1, y_test_1 = run_elliptic_preprocessing_pipeline(last_train_time_step=last_train_time_step,
                                                                             last_time_step=last_time_step,
                                                                             only_labeled=only_labeled)

# %%
X_test.drop(['time_step'], axis=1)
X_train.drop(['time_step'], axis=1)

# %%
idx_abnormal = np.where(y_train_1 == 1)[0]  # find abnormal samples indexes in the training set
X_train_1.drop(idx_abnormal, axis=0, inplace=True)  # remove abnormal samples from training (EFC trains with only benign instances)
y_train_1.drop(idx_abnormal, axis=0, inplace=True)  # remove the corresponding abonrmal training targets

# %%
X_train_1

# %%
y_train_1

# %%
clf = EnergyBasedFlowClassifier(n_bins=10, cutoff_quantile=0.8)

# %%
clf.fit(X_train_1, y_train_1, base_class=0)

# %%
y_pred_1, y_energies_1 = clf.predict(X_test_1, return_energies=True)

# %%
fpr, tpr, thresholds = roc_curve(y_test_1, y_pred_1)
roc_auc = auc(fpr, tpr)
print(roc_auc)

# %%
print(confusion_matrix(y_test_1, y_pred_1))
print(classification_report(y_test_1, y_pred_1))

# %%
y_pred_1

# %% [markdown]
# ### Dealing With Unbalanced Dataset

# %%
# Import Elliptic data set and set variables
last_time_step = 49
last_train_time_step = 34
only_labeled = True

# %%
# '1': 1, -> class1 (illicit)
# '2': 0, -> class2 (licit)
# 'unknown': 2 -> dropped
X_train, X_test, y_train, y_test = run_elliptic_preprocessing_pipeline(last_train_time_step=last_train_time_step,
                                                                             last_time_step=last_time_step,
                                                                             only_labeled=only_labeled)
# Out:
# /Users/kevinaraujo/repos/dissertation/PPCA-UnB-Dissertation/models/notebooks/research_aml_elliptic/src/experiments/general_functions/elliptic_data_preprocessing.py:46: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_classes.replace({"class": {"1": 1, "2": 0, "unknown": 2}}, inplace=True)

# %%
df_train = pd.concat([X_train, y_train], axis=1)

# %%
df_test = pd.concat([X_test, y_test], axis=1)

# %%
df_train
# Out:
#        time_step  trans_feat_0  trans_feat_1  trans_feat_2  trans_feat_3  \
# 0              1      0.163054      1.963790     -0.646376     12.409294
# 1              1     -0.005027      0.578941     -0.091383      4.380281
# 2              1     -0.147852     -0.184668     -1.201369     -0.121970
# 3              1     -0.151357     -0.184668     -1.201369     -0.121970
# 4              1     -0.172306     -0.184668     -1.201369      0.028105
# ...          ...           ...           ...           ...           ...
# 29889         34     -0.172968     -0.071395      0.463609     -0.121970
# 29890         34     -0.172924     -0.107411      1.018602     -0.121970
# 29891         34     -0.172897     -0.070152      0.463609     -0.121970
# 29892         34     -0.155367     -0.081852      0.463609     -0.121970
# 29893         34     -0.172981     -0.070152      0.463609     -0.121970
#
#        trans_feat_4  trans_feat_5  trans_feat_6  trans_feat_7  trans_feat_8  \
# 0         -0.063725      9.782742     12.414558     -0.163645     -0.115831
# 1         -0.063725      4.667146      0.851305     -0.163645     -0.144554
# 2         -0.043875     -0.113002     -0.061584     -0.137933     -0.144108
# 3         -0.043875     -0.113002     -0.061584     -0.141519     -0.147643
# 4         -0.043875     -0.029140      0.242712     -0.163640     -0.169115
# ...             ...           ...           ...           ...           ...
# 29889     -0.043875     -0.113002     -0.061584     -0.163627     -0.169442
# 29890     -0.063725     -0.113002     -0.061584     -0.163583     -0.169398
# 29891     -0.043875     -0.113002     -0.061584     -0.163555     -0.169371
# 29892     -0.043875     -0.113002     -0.061584     -0.145619     -0.151686
# 29893     -0.043875     -0.113002     -0.061584     -0.163641     -0.169455
#
#        ...  agg_feat_63  agg_feat_64  agg_feat_65  agg_feat_66  agg_feat_67  \
# 0      ...    -0.613614     0.241128     0.241406     1.072793     0.085530
# 1      ...    -0.613614     0.241128     0.241406     0.604120     0.008632
# 2      ...    -0.613614     0.241128     0.241406     0.018279    -0.087490
#
#
#        ...  agg_feat_62  agg_feat_63  agg_feat_64  agg_feat_65  agg_feat_66  \
# 27064  ...    -0.577099    -0.563154     0.241128     0.241406    -0.098889
# 25134  ...    -0.577099     0.118049     0.241128     0.241406    -0.098889
# 36701  ...    -0.577099    -0.462235     0.241128     0.241406     0.018279
# 26202  ...    -0.577099    -0.323472     0.241128     0.241406     0.018279
# 25619  ...    -0.577099    -0.310857     0.241128     0.241406     0.018279
# ...    ...          ...          ...          ...          ...          ...
# 13299  ...    -0.542583    -0.596794     1.039938     1.040059    -0.098889
# 29085  ...    -0.539735    -0.582077     1.461330     1.461369     0.018279
# 7138   ...    -0.577099    -0.600999     0.241128     0.241406     0.018279
# 33672  ...    -0.577099     0.294657     0.241128     0.241406     0.018279
# 11945  ...     0.155250     0.017130     1.461330     1.461369    -0.098889
#
#        agg_feat_67  agg_feat_68  agg_feat_69  agg_feat_70  agg_feat_71
# 27064    -0.106715    -0.131155    -0.183671    -0.120613    -0.119792
# 25134    -0.106715    -0.131155    -0.183671    -0.120613    -0.119792
# 36701    -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# 26202    -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# 25619    -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# ...            ...          ...          ...          ...          ...
# 13299    -0.049041    -0.066526    -0.083166    -0.388145    -0.674617
# 29085    -0.029817     0.008288     0.031697    -1.760926    -1.760984
# 7138     -0.068266    -0.093204    -0.040092     1.299939     1.301521
# 33672    -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# 11945    -0.087490    -0.084674    -0.140597    -1.760926    -1.760984
#
# [9090 rows x 166 columns]

# %%
y
# Out:
# 27064    1
# 25134    1
# 36701    1
# 26202    1
# 25619    1
#         ..
# 13299    0
# 29085    0
# 7138     0
# 33672    1
# 11945    0
# Name: class, Length: 9090, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=139, stratify=y, shuffle=True, test_size=0.3
)

# %%
clf = EnergyBasedFlowClassifier(n_bins=10, cutoff_quantile=0.75)

# %%
clf.fit(X_train, y_train, base_class=0)
# Out:
# EnergyBasedFlowClassifier(cutoff_quantile=0.75, n_bins=10)

# %%
y_pred, y_energies = clf.predict(X_test, return_energies=True)

# %%
# ploting energies
benign = np.where(y_test == 0)[0]
malicious = np.where(y_test == 1)[0]

benign_energies = y_energies[benign]
malicious_energies = y_energies[malicious]
cutoff = clf.estimators_[0].cutoff_

bins = np.histogram(y_energies, bins=60)[1]

plt.hist(
    malicious_energies,
    bins,
    facecolor="#006680",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="malicious",
)
plt.hist(
    benign_energies,
    bins,
    facecolor="#b3b3b3",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="benign",
)
plt.axvline(cutoff, color="r", linestyle="dashed", linewidth=1)
plt.legend()

plt.xlabel("Energy", fontsize=12)
plt.ylabel("Density", fontsize=12)

plt.savefig(f'{results_efc}/4_balanced_dataset.png')

# %%
metric_dict_3 = {
    "Technique": "Balanced Dataset",
    "accuracy": accuracy_score(y_test, y_pred),
    "f1": f1_score(y_test, y_pred, pos_label=1),
    "f1_micro": f1_score(y_test, y_pred, average="micro"),
    "f1_macro": f1_score(y_test, y_pred, average="macro"),
    "precision": precision_score(y_test, y_pred),
    "recall": recall_score(y_test, y_pred),
    "roc_auc": roc_auc_score(y_test, y_pred),
}

# %%
pprint(metric_dict_3)
# Out:
# {'Technique': 'Balanced Dataset',
#  'accuracy': 0.7675100843417675,
#  'f1': np.float64(0.7876758204956463),
#  'f1_macro': np.float64(0.7653938259690549),
#  'f1_micro': np.float64(0.7675100843417675),
#  'precision': np.float64(0.7245841035120147),
#  'recall': np.float64(0.8628026412325752),
#  'roc_auc': np.float64(0.7675450156309505)}

# %%
df_efc_metrics.loc[3] = metric_dict_3
df_efc_metrics
# Out:
#             Technique  accuracy        f1  f1_micro  f1_macro  precision  \
# 0  Unbalanced Dataset  0.842891  0.003045  0.842891  0.458886   0.002591
# 1   Unlabeled Dataset  0.260044       NaN  0.260044  0.169561        NaN
# 2   No Unlabeled Data  0.909238       NaN  0.909238  0.318326        NaN
# 3    Balanced Dataset  0.767510  0.787676  0.767510  0.765394   0.724584
#
#      recall   roc_auc
# 0  0.003693  0.452447
# 1       NaN       NaN
# 2       NaN       NaN
# 3  0.862803  0.767545

# %% [markdown]
# ### SMOTE Technique

# %%
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import make_pipeline as imbalanced_make_pipeline
from sklearn.model_selection import train_test_split, RandomizedSearchCV

# %%
# Import Elliptic data set and set variables
last_time_step = 49
last_train_time_step = 34
only_labeled = True

# %%
def recreate_original_df():
    X_train, X_test, y_train, y_test = run_elliptic_preprocessing_pipeline(last_train_time_step=last_train_time_step,
                                                                             last_time_step=last_time_step,
                                                                             only_labeled=only_labeled)
    df_train = pd.concat([X_train, y_train], axis=1)
    df_test = pd.concat([X_test, y_test], axis=1)
    df = pd.concat([df_train, df_test])
    X = df.drop(['class'], axis=1)
    y = df['class']

    return X, y

# %%
X, y = recreate_original_df()
# Out:
# /Users/kevinaraujo/repos/dissertation/PPCA-UnB-Dissertation/models/notebooks/research_aml_elliptic/src/experiments/general_functions/elliptic_data_preprocessing.py:46: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_classes.replace({"class": {"1": 1, "2": 0, "unknown": 2}}, inplace=True)

# %%
orig_X_train, orig_X_test, orig_y_train, orig_y_test = train_test_split(X, y, test_size=0.2, random_state=139, shuffle=False)

# %%
orig_X_train.iloc[1]

# %%
# efc_params = {'cutoff_quantile': np.linspace(0.5, 1, 21).tolist(), 'n_bins': list(range(10, 165, 10))}

efc_params = {'cutoff_quantile': [0.7, 0.8, 0.9], 'n_bins': [10, 20, 30]}

# %%
efc_smt = EnergyBasedFlowClassifier()

# %%
rand_efc_smt = RandomizedSearchCV(EnergyBasedFlowClassifier(), efc_params, n_iter=4)

# %%
s_kfold = StratifiedKFold(n_splits=5, random_state=None, shuffle=False)

# %%
accuracy_lst = []
precision_lst = []
recall_lst = []
f1_lst = []
auc_lst = []

# %%
for train, test in s_kfold.split(orig_X_train, orig_y_train):
    # SMOTE happens during Cross Validation not before..
    pipeline = imbalanced_make_pipeline(SMOTE(sampling_strategy='minority', n_jobs=-1), rand_efc_smt, verbose=True)
    print(pipeline)
    model = pipeline.fit(orig_X_train.iloc[:10000], orig_y_train.iloc[:10000])
    print(model)
    best_est = rand_efc_smt.best_estimator_
    print(best_est)
    prediction = best_est.predict(orig_X_train.iloc[test])
    print(prediction)

    accuracy_lst.append(pipeline.score(orig_X_train.iloc[test], orig_y_train.iloc[test]))
    precision_lst.append(precision_score(orig_y_train.iloc[test], prediction))
    recall_lst.append(recall_score(orig_y_train.iloc[test], prediction))
    f1_lst.append(f1_score(orig_y_train.iloc[test], prediction))
    auc_lst.append(roc_auc_score(orig_y_train.iloc[test], prediction))
    print('end of batch')

# %%
print('---' * 45, end='\n\n')
print("accuracy: {}".format(np.mean(accuracy_lst)))
print("precision: {}".format(np.mean(precision_lst)))
print("recall: {}".format(np.mean(recall_lst)))
print("f1: {}".format(np.mean(f1_lst)))
print('---' * 45)

# %% [markdown]
# ### SMOTE Technique V2

# %%
X, y = recreate_original_df()
# Out:
# /Users/kevinaraujo/repos/dissertation/PPCA-UnB-Dissertation/models/notebooks/research_aml_elliptic/src/experiments/general_functions/elliptic_data_preprocessing.py:46: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_classes.replace({"class": {"1": 1, "2": 0, "unknown": 2}}, inplace=True)

# %%
smote = SMOTE(sampling_strategy='minority', n_jobs=-1)

# %%
X_sm, y_sm = smote.fit_resample(X, y)
# Out:
# /Users/kevinaraujo/.pyenv/versions/masters/lib/python3.12/site-packages/imblearn/over_sampling/_smote/base.py:370: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(

# %%
X_sm
# Out:
#        time_step  trans_feat_0  trans_feat_1  trans_feat_2  trans_feat_3  \
# 0              1      0.163054      1.963790     -0.646376     12.409294
# 1              1     -0.005027      0.578941     -0.091383      4.380281
# 2              1     -0.147852     -0.184668     -1.201369     -0.121970
# 3              1     -0.151357     -0.184668     -1.201369     -0.121970
# 4              1     -0.172306     -0.184668     -1.201369      0.028105
# ...          ...           ...           ...           ...           ...
# 84033         29     -0.150649     -0.107012     -1.201369     -0.121970
# 84034          9     -0.172166     -0.158783     -1.201369     -0.121970
# 84035         20     -0.172181     -0.161532      1.018602     -0.121970
# 84036         39     -0.172926      0.027320      0.731814     -0.121970
# 84037         25     -0.170358     -0.157506      1.018602     -0.121970
#
#        trans_feat_4  trans_feat_5  trans_feat_6  trans_feat_7  trans_feat_8  \
# 0         -0.063725      9.782742     12.414558     -0.163645     -0.115831
# 1         -0.063725      4.667146      0.851305     -0.163645     -0.144554
# 2         -0.043875     -0.113002     -0.061584     -0.137933     -0.144108
# 3         -0.043875     -0.113002     -0.061584     -0.141519     -0.147643
# 4         -0.043875     -0.029140      0.242712     -0.163640     -0.169115
# ...             ...           ...           ...           ...           ...
# 84033     -0.043875     -0.113002     -0.061584     -0.140793     -0.146927
# 84034     -0.063725     -0.113002     -0.061584     -0.162809     -0.168635
# 84035     -0.063725     -0.113002     -0.061584     -0.162824     -0.168650
# 84036     -0.063725     -0.113002     -0.061584     -0.163582     -0.169398
# 84037     -0.063725     -0.113002     -0.061584     -0.160959     -0.166811
#
#        ...  agg_feat_62  agg_feat_63  agg_feat_64  agg_feat_65  agg_feat_66  \
# 0      ...    -0.577099    -0.613614     0.241128     0.241406     1.072793
# 1      ...    -0.577099    -0.613614     0.241128     0.241406     0.604120
# 2      ...    -0.577099    -0.613614     0.241128     0.241406     0.018279
# 3      ...    -0.539735    -0.582077    -0.979074    -0.978556     0.018279
# 4      ...    -0.577099    -0.600999     0.241128     0.241406     0.018279
# ...    ...          ...          ...          ...          ...          ...
# 84033  ...    -0.519856    -0.565299    -0.979074    -0.978556     0.018279
# 84034  ...    -0.577099    -0.222553     0.241128     0.241406     0.018279
# 84035  ...    -0.577099    -0.053725     0.241128     0.241406    -0.062757
# 84036  ...    -0.577099    -0.613614     0.241128     0.241406     0.018279
# 84037  ...    -0.577099    -0.521462     0.241128     0.241406    -0.021440
#
#        agg_feat_67  agg_feat_68  agg_feat_69  agg_feat_70  agg_feat_71
# 0         0.085530    -0.131155     0.677799    -0.120613    -0.119792
# 1         0.008632    -0.131155     0.333211    -0.120613    -0.119792
# 2        -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# 3        -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# 4        -0.068266    -0.084674    -0.054450    -1.760926    -1.760984
# ...            ...          ...          ...          ...          ...
# 84033    -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# 84034    -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# 84035    -0.100786    -0.131155    -0.157105    -0.120613    -0.119792
# 84036    -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# 84037    -0.094007    -0.131155    -0.126727    -0.120613    -0.119792
#
# [84038 rows x 166 columns]

# %%
y_sm
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 84033    1
# 84034    1
# 84035    1
# 84036    1
# 84037    1
# Name: class, Length: 84038, dtype: int64

# %%
len(np.where(y_sm == 0)[0])
# Out:
# 42019

# %%
len(np.where(y_sm == 1)[0])
# Out:
# 42019

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_sm, y_sm, random_state=139, stratify=y_sm, shuffle=True, test_size=0.3
)

# %%
clf = EnergyBasedFlowClassifier(n_bins=10, cutoff_quantile=0.75)

# %%
clf.fit(X_train, y_train, base_class=0)
# Out:
# EnergyBasedFlowClassifier(cutoff_quantile=0.75, n_bins=10)

# %%
y_pred, y_energies = clf.predict(X_test, return_energies=True)

# %%
# ploting energies
benign = np.where(y_test == 0)[0]
malicious = np.where(y_test == 1)[0]

benign_energies = y_energies[benign]
malicious_energies = y_energies[malicious]
cutoff = clf.estimators_[0].cutoff_

bins = np.histogram(y_energies, bins=60)[1]

plt.hist(
    malicious_energies,
    bins,
    facecolor="#006680",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="malicious",
)
plt.hist(
    benign_energies,
    bins,
    facecolor="#b3b3b3",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="benign",
)
plt.axvline(cutoff, color="r", linestyle="dashed", linewidth=1)
plt.legend()

plt.xlabel("Energy", fontsize=12)
plt.ylabel("Density", fontsize=12)

plt.savefig(f'{results_efc}/5_smote.png')

# %%
metric_dict_4 = {
    "Technique": "Smote",
    "accuracy": accuracy_score(y_test, y_pred),
    "f1": f1_score(y_test, y_pred, pos_label=1),
    "f1_micro": f1_score(y_test, y_pred, average="micro"),
    "f1_macro": f1_score(y_test, y_pred, average="macro"),
    "precision": precision_score(y_test, y_pred),
    "recall": recall_score(y_test, y_pred),
    "roc_auc": roc_auc_score(y_test, y_pred),
}

# %%
pprint(metric_dict_4)
# Out:
# {'Technique': 'Smote',
#  'accuracy': 0.7966841186736475,
#  'f1': np.float64(0.8098946743806557),
#  'f1_macro': np.float64(0.7956975503190575),
#  'f1_micro': np.float64(0.7966841186736475),
#  'precision': np.float64(0.7604819612759437),
#  'recall': np.float64(0.8661748373790259),
#  'roc_auc': np.float64(0.7966841186736475)}

# %%
df_efc_metrics.loc[4] = metric_dict_4
df_efc_metrics
# Out:
#             Technique  accuracy        f1  f1_micro  f1_macro  precision  \
# 0  Unbalanced Dataset  0.842891  0.003045  0.842891  0.458886   0.002591
# 1   Unlabeled Dataset  0.260044       NaN  0.260044  0.169561        NaN
# 2   No Unlabeled Data  0.909238       NaN  0.909238  0.318326        NaN
# 3    Balanced Dataset  0.767510  0.787676  0.767510  0.765394   0.724584
# 4               Smote  0.796684  0.809895  0.796684  0.795698   0.760482
#
#      recall   roc_auc
# 0  0.003693  0.452447
# 1       NaN       NaN
# 2       NaN       NaN
# 3  0.862803  0.767545
# 4  0.866175  0.796684

# %% [markdown]
# ### Stratified K-Fold CV

# %%
from sklearn.model_selection import StratifiedKFold

# %%
kf = StratifiedKFold(n_splits=5, shuffle=False)

# %% [markdown]
# ### Hyperparameter Tuning Using GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
X, y = recreate_original_df()
# Out:
# /Users/kevinaraujo/repos/dissertation/PPCA-UnB-Dissertation/models/notebooks/research_aml_elliptic/src/experiments/general_functions/elliptic_data_preprocessing.py:46: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_classes.replace({"class": {"1": 1, "2": 0, "unknown": 2}}, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=139, stratify=y, test_size=0.3
)

# %%
efc = EnergyBasedFlowClassifier()

# %%
efc_params = {'cutoff_quantile': [0.7, 0.8, 0.9], 'n_bins': [10, 20, 30]}

# %%
grid_efc = GridSearchCV(efc, param_grid=efc_params, cv=kf, scoring='recall')

# %%
grid_efc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=EnergyBasedFlowClassifier(),
#              param_grid={'cutoff_quantile': [0.7, 0.8, 0.9],
#                          'n_bins': [10, 20, 30]},
#              scoring='recall')

# %%
print('Best parameters:', grid_efc.best_params_)
print('Best score:', grid_efc.best_score_)
# Out:
# Best parameters: {'cutoff_quantile': 0.7, 'n_bins': 10}
# Best score: 0.38887868645281043

# %%
y_pred = grid_efc.predict(X_test)

# %%
# ploting energies
benign = np.where(y_test == 0)[0]
malicious = np.where(y_test == 1)[0]

benign_energies = y_energies[benign]
malicious_energies = y_energies[malicious]
cutoff = clf.estimators_[0].cutoff_

bins = np.histogram(y_energies, bins=60)[1]

plt.hist(
    malicious_energies,
    bins,
    facecolor="#006680",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="malicious",
)
plt.hist(
    benign_energies,
    bins,
    facecolor="#b3b3b3",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="benign",
)
plt.axvline(cutoff, color="r", linestyle="dashed", linewidth=1)
plt.legend()

plt.xlabel("Energy", fontsize=12)
plt.ylabel("Density", fontsize=12)

plt.savefig(f'{results_efc}/6_grid_search_cv.png')

# %%
metric_dict_5 = {
    "Technique": "Grid Search CV",
    "accuracy": accuracy_score(y_test, y_pred),
    "f1": f1_score(y_test, y_pred, pos_label=1),
    "f1_micro": f1_score(y_test, y_pred, average="micro"),
    "f1_macro": f1_score(y_test, y_pred, average="macro"),
    "precision": precision_score(y_test, y_pred),
    "recall": recall_score(y_test, y_pred),
    "roc_auc": roc_auc_score(y_test, y_pred),
}

# %%
pprint(metric_dict_5)
# Out:
# {'Technique': 'Grid Search CV',
#  'accuracy': 0.6496778811739442,
#  'f1': np.float64(0.16797007820469229),
#  'f1_macro': np.float64(0.4730502308695055),
#  'f1_micro': np.float64(0.6496778811739442),
#  'precision': np.float64(0.10934041611332448),
#  'recall': np.float64(0.3621700879765396),
#  'roc_auc': np.float64(0.5214785074183825)}

# %%
df_efc_metrics.loc[5] = metric_dict_5
df_efc_metrics
# Out:
#             Technique  accuracy        f1  f1_micro  f1_macro  precision  \
# 0  Unbalanced Dataset  0.842891  0.003045  0.842891  0.458886   0.002591
# 1   Unlabeled Dataset  0.260044       NaN  0.260044  0.169561        NaN
# 2   No Unlabeled Data  0.909238       NaN  0.909238  0.318326        NaN
# 3    Balanced Dataset  0.767510  0.787676  0.767510  0.765394   0.724584
# 4               Smote  0.796684  0.809895  0.796684  0.795698   0.760482
# 5      Grid Search CV  0.649678  0.167970  0.649678  0.473050   0.109340
#
#      recall   roc_auc
# 0  0.003693  0.452447
# 1       NaN       NaN
# 2       NaN       NaN
# 3  0.862803  0.767545
# 4  0.866175  0.796684
# 5  0.362170  0.521479

# %% [markdown]
# ### Random Resampling Imbalanced Datasets

# %% [markdown]
# #### Random Oversampling

# %% [markdown]
# The random oversampling may increase the likelihood of occurring overfitting, since it makes exact copies of the minority class examples. Let's say every data point from the minority class is copied 6 times before making the splits. If we did a 3-fold validation, each fold has (on average) 2 copies of each point! In this way a classifier might construct rules that are apparently accurate, but actually cover one replicated example.

# %%
X, y = recreate_original_df()
# Out:
# /Users/kevinaraujo/repos/dissertation/PPCA-UnB-Dissertation/models/notebooks/research_aml_elliptic/src/experiments/general_functions/elliptic_data_preprocessing.py:46: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_classes.replace({"class": {"1": 1, "2": 0, "unknown": 2}}, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=139, stratify=y, test_size=0.3
)

# %%
from imblearn.over_sampling import RandomOverSampler
# define oversampling strategy
ros = RandomOverSampler(random_state=139)

# %%
# fit and apply the transform
X_over, y_over = ros.fit_resample(X_train, y_train)

# %%
print('Genuine:', y_over.value_counts()[0], '/', round(y_over.value_counts()[0]/len(y_over) * 100,2), '% of the dataset')
print('Frauds:', y_over.value_counts()[1], '/',round(y_over.value_counts()[1]/len(y_over) * 100,2), '% of the dataset')
# Out:
# Genuine: 29413 / 50.0 % of the dataset
# Frauds: 29413 / 50.0 % of the dataset

# %% [markdown]
# ##### Imbalanced-Learn Pipeline

# %% [markdown]
# The purpose of the pipeline is to assemble several steps that can be cross-validated together while setting different parameters.
#
# During the cross-validation process we should split into training and validation segments. Then, on each segment, we should:
#
# 1.    Oversample the minority class.
# 2.    Train the classifier on the training segment.
# 3.    Validate the classifier on the remaining segment.

# %%
kf = StratifiedKFold(n_splits=5, shuffle=False)

# %%
from imblearn.pipeline import Pipeline, make_pipeline

random_overs_pipeline = make_pipeline(RandomOverSampler(random_state=139), 
                              EnergyBasedFlowClassifier())

# %%
score2 = cross_val_score(random_overs_pipeline, X_train, y_train, scoring='recall', cv=kf)
print("Cross Validation Recall Scores are: {}".format(score2))
print("Average Cross Validation Recall score: {}".format(score2.mean()))
# Out:
# Cross Validation Recall Scores are: [0.78649922 0.80503145 0.80503145 0.80974843 0.80503145]
# Average Cross Validation Recall score: 0.8022683964732483

# %% [markdown]
# #### GridSearchCV

# %%
## There should be two underscores between estimator name and it's parameters in a Pipeline
new_params = {'energybasedflowclassifier__' + key: efc_params[key] for key in efc_params}

# %%
new_params
# Out:
# {'energybasedflowclassifier__cutoff_quantile': [0.7, 0.8, 0.9],
#  'energybasedflowclassifier__n_bins': [10, 20, 30]}

# %%
grid_over_efc = GridSearchCV(random_overs_pipeline, param_grid=new_params, cv=kf, scoring='recall',
                        return_train_score=True)

# %%
grid_over_efc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=Pipeline(steps=[('randomoversampler',
#                                         RandomOverSampler(random_state=139)),
#                                        ('energybasedflowclassifier',
#                                         EnergyBasedFlowClassifier(cutoff_quantile=0.75,
#                                                                   n_bins=10))]),
#              param_grid={'energybasedflowclassifier__cutoff_quantile': [0.7,
#                                                                         0.8,
#                                                                         0.9],
#                          'energybasedflowclassifier__n_bins': [10, 20, 30]},
#              return_train_score=True, scoring='recall')

# %%
print('Best parameters:', grid_efc.best_params_)
print('Best score:', grid_efc.best_score_)
# Out:
# Best parameters: {'cutoff_quantile': 0.7, 'n_bins': 10}
# Best score: 0.38887868645281043

# %% [markdown]
# #### Confusion matrix and scores

# %%
y_pred, y_energies = grid_over_efc.best_estimator_.named_steps['energybasedflowclassifier'].predict(X_test, return_energies=True)

# %%
# ploting energies
benign = np.where(y_test == 0)[0]
malicious = np.where(y_test == 1)[0]

benign_energies = y_energies[benign]
malicious_energies = y_energies[malicious]
cutoff = grid_over_efc.best_estimator_.named_steps['energybasedflowclassifier'].estimators_[0].cutoff_

bins = np.histogram(y_energies, bins=60)[1]

plt.hist(
    malicious_energies,
    bins,
    facecolor="#006680",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="malicious",
)
plt.hist(
    benign_energies,
    bins,
    facecolor="#b3b3b3",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="benign",
)
plt.axvline(cutoff, color="r", linestyle="dashed", linewidth=1)
plt.legend()

plt.xlabel("Energy", fontsize=12)
plt.ylabel("Density", fontsize=12)

plt.savefig(f'{results_efc}/7_random_oversampling.png')

# %%
metric_dict_6 = {
    "Technique": "Random Oversampling",
    "accuracy": accuracy_score(y_test, y_pred),
    "f1": f1_score(y_test, y_pred, pos_label=1),
    "f1_micro": f1_score(y_test, y_pred, average="micro"),
    "f1_macro": f1_score(y_test, y_pred, average="macro"),
    "precision": precision_score(y_test, y_pred),
    "recall": recall_score(y_test, y_pred),
    "roc_auc": roc_auc_score(y_test, y_pred),
}

# %%
pprint(metric_dict_6)
# Out:
# {'Technique': 'Random Oversampling',
#  'accuracy': 0.6886900501073729,
#  'f1': np.float64(0.3517662840959905),
#  'f1_macro': np.float64(0.5734621538703305),
#  'f1_micro': np.float64(0.6886900501073729),
#  'precision': np.float64(0.2207670720299345),
#  'recall': np.float64(0.8651026392961877),
#  'roc_auc': np.float64(0.7673522081139037)}

# %%
df_efc_metrics.loc[6] = metric_dict_6
df_efc_metrics
# Out:
#              Technique  accuracy        f1  f1_micro  f1_macro  precision  \
# 0   Unbalanced Dataset  0.842891  0.003045  0.842891  0.458886   0.002591
# 1    Unlabeled Dataset  0.260044       NaN  0.260044  0.169561        NaN
# 2    No Unlabeled Data  0.909238       NaN  0.909238  0.318326        NaN
# 3     Balanced Dataset  0.767510  0.787676  0.767510  0.765394   0.724584
# 4                Smote  0.796684  0.809895  0.796684  0.795698   0.760482
# 5       Grid Search CV  0.649678  0.167970  0.649678  0.473050   0.109340
# 6  Random Oversampling  0.688690  0.351766  0.688690  0.573462   0.220767
#
#      recall   roc_auc
# 0  0.003693  0.452447
# 1       NaN       NaN
# 2       NaN       NaN
# 3  0.862803  0.767545
# 4  0.866175  0.796684
# 5  0.362170  0.521479
# 6  0.865103  0.767352

# %% [markdown]
# #### Random Undersampling Imbalanced Datasets

# %% [markdown]
# Random undersampling involves randomly selecting examples from the majority class to delete from the training dataset. This approach may be more suitable for those datasets where there is a class imbalance although a sufficient number of examples in the minority class, such a useful model can be fit.

# %%
X, y = recreate_original_df()
# Out:
# /Users/kevinaraujo/repos/dissertation/PPCA-UnB-Dissertation/models/notebooks/research_aml_elliptic/src/experiments/general_functions/elliptic_data_preprocessing.py:46: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_classes.replace({"class": {"1": 1, "2": 0, "unknown": 2}}, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=139, stratify=y, test_size=0.3
)

# %%
from imblearn.under_sampling import RandomUnderSampler
# define oversampling strategy
rus = RandomUnderSampler(random_state=139)

# %%
# fit and apply the transform
X_under, y_under = rus.fit_resample(X_train, y_train)

# %%
print('Genuine:', y_under.value_counts()[0], '/', round(y_under.value_counts()[0]/len(y_under) * 100,2), '% of the dataset')
print('Frauds:', y_under.value_counts()[1], '/',round(y_under.value_counts()[1]/len(y_under) * 100,2), '% of the dataset')
# Out:
# Genuine: 3181 / 50.0 % of the dataset
# Frauds: 3181 / 50.0 % of the dataset

# %% [markdown]
# ##### Pipeline

# %%
kf = StratifiedKFold(n_splits=5, shuffle=False)

# %%
from imblearn.pipeline import Pipeline, make_pipeline

random_under_pipeline = make_pipeline(rus, EnergyBasedFlowClassifier())

# %%
score_under = cross_val_score(random_under_pipeline, X_under, y_under, scoring='recall', cv=kf)

print("Cross Validation Recall Scores are: {}".format(score_under))
print("Average Cross Validation Recall score: {}".format(score_under.mean()))
# Out:
# Cross Validation Recall Scores are: [0.85377358 0.86185243 0.84119497 0.86477987 0.85534591]
# Average Cross Validation Recall score: 0.8553893545807292

# %% [markdown]
# #### GridSearchCV Random Undersampling

# %%
new_params = {'energybasedflowclassifier__' + key: efc_params[key] for key in efc_params}

# %%
grid_under_efc = GridSearchCV(random_under_pipeline, param_grid=new_params, cv=kf, scoring='recall',
                        return_train_score=True)

# %%
grid_under_efc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=Pipeline(steps=[('randomundersampler',
#                                         RandomUnderSampler(random_state=139)),
#                                        ('energybasedflowclassifier',
#                                         EnergyBasedFlowClassifier())]),
#              param_grid={'energybasedflowclassifier__cutoff_quantile': [0.7,
#                                                                         0.8,
#                                                                         0.9],
#                          'energybasedflowclassifier__n_bins': [10, 20, 30]},
#              return_train_score=True, scoring='recall')

# %%
print('Best parameters:', grid_under_efc.best_params_)
print('Best score:', grid_under_efc.best_score_)
# Out:
# Best parameters: {'energybasedflowclassifier__cutoff_quantile': 0.7, 'energybasedflowclassifier__n_bins': 30}
# Best score: 0.9855395278575871

# %% [markdown]
# #### Confusion matrix and scores

# %%
y_pred, y_energies = grid_under_efc.best_estimator_.named_steps['energybasedflowclassifier'].predict(X_test, return_energies=True)

# %%
# ploting energies
benign = np.where(y_test == 0)[0]
malicious = np.where(y_test == 1)[0]

benign_energies = y_energies[benign]
malicious_energies = y_energies[malicious]
cutoff = grid_under_efc.best_estimator_.named_steps['energybasedflowclassifier'].estimators_[0].cutoff_

bins = np.histogram(y_energies, bins=60)[1]

plt.hist(
    malicious_energies,
    bins,
    facecolor="#006680",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="malicious",
)
plt.hist(
    benign_energies,
    bins,
    facecolor="#b3b3b3",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="benign",
)
plt.axvline(cutoff, color="r", linestyle="dashed", linewidth=1)
plt.legend()

plt.xlabel("Energy", fontsize=12)
plt.ylabel("Density", fontsize=12)

plt.savefig(f'{results_efc}/8_random_under_sampling.png')

# %%
metric_dict_7 = {
    "Technique": "Random Undersampling",
    "accuracy": accuracy_score(y_test, y_pred),
    "f1": f1_score(y_test, y_pred, pos_label=1),
    "f1_micro": f1_score(y_test, y_pred, average="micro"),
    "f1_macro": f1_score(y_test, y_pred, average="macro"),
    "precision": precision_score(y_test, y_pred),
    "recall": recall_score(y_test, y_pred),
    "roc_auc": roc_auc_score(y_test, y_pred),
}

# %%
pprint(metric_dict_7)
# Out:
# {'Technique': 'Random Undersampling',
#  'accuracy': 0.4727988546886185,
#  'f1': np.float64(0.2663611913537205),
#  'f1_macro': np.float64(0.4274658311385663),
#  'f1_micro': np.float64(0.4727988546886185),
#  'precision': np.float64(0.15412103746397696),
#  'recall': np.float64(0.9802052785923754),
#  'roc_auc': np.float64(0.699050759239072)}

# %%
df_efc_metrics.loc[7] = metric_dict_7
df_efc_metrics
# Out:
#               Technique  accuracy        f1  f1_micro  f1_macro  precision  \
# 0    Unbalanced Dataset  0.842891  0.003045  0.842891  0.458886   0.002591
# 1     Unlabeled Dataset  0.260044       NaN  0.260044  0.169561        NaN
# 2     No Unlabeled Data  0.909238       NaN  0.909238  0.318326        NaN
# 3      Balanced Dataset  0.767510  0.787676  0.767510  0.765394   0.724584
# 4                 Smote  0.796684  0.809895  0.796684  0.795698   0.760482
# 5        Grid Search CV  0.649678  0.167970  0.649678  0.473050   0.109340
# 6   Random Oversampling  0.688690  0.351766  0.688690  0.573462   0.220767
# 7  Random Undersampling  0.472799  0.266361  0.472799  0.427466   0.154121
#
#      recall   roc_auc
# 0  0.003693  0.452447
# 1       NaN       NaN
# 2       NaN       NaN
# 3  0.862803  0.767545
# 4  0.866175  0.796684
# 5  0.362170  0.521479
# 6  0.865103  0.767352
# 7  0.980205  0.699051

# %% [markdown]
# #### SMOTE GridSearchCV

# %%
X, y = recreate_original_df()
# Out:
# /Users/kevinaraujo/repos/dissertation/PPCA-UnB-Dissertation/models/notebooks/research_aml_elliptic/src/experiments/general_functions/elliptic_data_preprocessing.py:46: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_classes.replace({"class": {"1": 1, "2": 0, "unknown": 2}}, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=139, stratify=y, test_size=0.3
)

# %%
kf = StratifiedKFold(n_splits=5, shuffle=False)

# %%
from imblearn.over_sampling import SMOTE

smote_pipeline = make_pipeline(SMOTE(random_state=139), 
                              EnergyBasedFlowClassifier(cutoff_quantile=0.7, n_bins=10))

# %%
score_smote = cross_val_score(smote_pipeline, X_train, y_train, scoring='recall', cv=kf)

print("Cross Validation Recall Scores are: {}".format(score_smote))
print("Average Cross Validation Recall score: {}".format(score_smote.mean()))
# Out:
# Cross Validation Recall Scores are: [0.83202512 0.84591195 0.86477987 0.85062893 0.84591195]
# Average Cross Validation Recall score: 0.8478515644283838

# %%
new_params = {'energybasedflowclassifier__' + key: efc_params[key] for key in efc_params}

# %%
smote_efc = GridSearchCV(smote_pipeline, param_grid=new_params, cv=kf, scoring='recall',
                        return_train_score=True)

# %%
smote_efc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=Pipeline(steps=[('smote', SMOTE(random_state=139)),
#                                        ('energybasedflowclassifier',
#                                         EnergyBasedFlowClassifier(cutoff_quantile=0.7,
#                                                                   n_bins=10))]),
#              param_grid={'energybasedflowclassifier__cutoff_quantile': [0.7,
#                                                                         0.8,
#                                                                         0.9],
#                          'energybasedflowclassifier__n_bins': [10, 20, 30]},
#              return_train_score=True, scoring='recall')

# %%
print('Best parameters:', smote_efc.best_params_)
print('Best score:', smote_efc.best_score_)
# Out:
# Best parameters: {'energybasedflowclassifier__cutoff_quantile': 0.7, 'energybasedflowclassifier__n_bins': 20}
# Best score: 0.8566501782135205

# %%
y_pred, y_energies = smote_efc.best_estimator_.named_steps['energybasedflowclassifier'].predict(X_test, return_energies=True)

# %%
# ploting energies
benign = np.where(y_test == 0)[0]
malicious = np.where(y_test == 1)[0]

benign_energies = y_energies[benign]
malicious_energies = y_energies[malicious]
cutoff = smote_efc.best_estimator_.named_steps['energybasedflowclassifier'].estimators_[0].cutoff_

bins = np.histogram(y_energies, bins=60)[1]

plt.hist(
    malicious_energies,
    bins,
    facecolor="#006680",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="malicious",
)
plt.hist(
    benign_energies,
    bins,
    facecolor="#b3b3b3",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="benign",
)
plt.axvline(cutoff, color="r", linestyle="dashed", linewidth=1)
plt.legend()

plt.xlabel("Energy", fontsize=12)
plt.ylabel("Density", fontsize=12)

plt.savefig(f'{results_efc}/9_smote_with_grid_search_cv.png')

# %%
metric_dict_8 = {
    "Technique": "Smote With GridSearch CV",
    "accuracy": accuracy_score(y_test, y_pred),
    "f1": f1_score(y_test, y_pred, pos_label=1),
    "f1_micro": f1_score(y_test, y_pred, average="micro"),
    "f1_macro": f1_score(y_test, y_pred, average="macro"),
    "precision": precision_score(y_test, y_pred),
    "recall": recall_score(y_test, y_pred),
    "roc_auc": roc_auc_score(y_test, y_pred),
}

# %%
pprint(metric_dict_8)
# Out:
# {'Technique': 'Smote With GridSearch CV',
#  'accuracy': 0.6912670007158196,
#  'f1': np.float64(0.35732379675160186),
#  'f1_macro': np.float64(0.5770791577850996),
#  'f1_micro': np.float64(0.6912670007158196),
#  'precision': np.float64(0.22423789040583506),
#  'recall': np.float64(0.8790322580645161),
#  'roc_auc': np.float64(0.7749912995859626)}

# %%
df_efc_metrics.loc[8] = metric_dict_8
df_efc_metrics
# Out:
#                   Technique  accuracy        f1  f1_micro  f1_macro  \
# 0        Unbalanced Dataset  0.842891  0.003045  0.842891  0.458886
# 1         Unlabeled Dataset  0.260044       NaN  0.260044  0.169561
# 2         No Unlabeled Data  0.909238       NaN  0.909238  0.318326
# 3          Balanced Dataset  0.767510  0.787676  0.767510  0.765394
# 4                     Smote  0.796684  0.809895  0.796684  0.795698
# 5            Grid Search CV  0.649678  0.167970  0.649678  0.473050
# 6       Random Oversampling  0.688690  0.351766  0.688690  0.573462
# 7      Random Undersampling  0.472799  0.266361  0.472799  0.427466
# 8  Smote With GridSearch CV  0.691267  0.357324  0.691267  0.577079
#
#    precision    recall   roc_auc
# 0   0.002591  0.003693  0.452447
# 1        NaN       NaN       NaN
# 2        NaN       NaN       NaN
# 3   0.724584  0.862803  0.767545
# 4   0.760482  0.866175  0.796684
# 5   0.109340  0.362170  0.521479
# 6   0.220767  0.865103  0.767352
# 7   0.154121  0.980205  0.699051
# 8   0.224238  0.879032  0.774991

# %% [markdown]
# #### Undersampling using Tomek Links

# %% [markdown]
# Tomek Links is an under-sampling technique that was developed in 1976 by Ivan Tomek. It is one of a modification from Condensed Nearest Neighbors (CNN). It can be used to find desired samples of data from the majority class that is having the lowest Euclidean distance with the minority class data and then remove it.

# %%
X, y = recreate_original_df()
# Out:
# /Users/kevinaraujo/repos/dissertation/PPCA-UnB-Dissertation/models/notebooks/research_aml_elliptic/src/experiments/general_functions/elliptic_data_preprocessing.py:46: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_classes.replace({"class": {"1": 1, "2": 0, "unknown": 2}}, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=139, stratify=y, test_size=0.3
)

# %%
from imblearn.under_sampling import TomekLinks

# define the undersampling method
#tomekU = TomekLinks(sampling_strategy='auto', n_jobs=-1)
tomekU = TomekLinks()

# fit and apply the transform
X_underT, y_underT = tomekU.fit_resample(X_train, y_train)

# %%
print('Genuine:', y_underT.value_counts()[0], '/', round(y_underT.value_counts()[0]/len(y_underT) * 100,2), '% of the dataset')
print('Frauds:', y_underT.value_counts()[1], '/',round(y_underT.value_counts()[1]/len(y_underT) * 100,2), '% of the dataset')
# Out:
# Genuine: 29257 / 90.19 % of the dataset
# Frauds: 3181 / 9.81 % of the dataset

# %% [markdown]
# #### Combining SMOTE and Tomek Links

# %%
from imblearn.combine import SMOTETomek

SMOTETomek_pipeline = make_pipeline(SMOTETomek(tomek=TomekLinks(sampling_strategy='majority')), 
                              EnergyBasedFlowClassifier(cutoff_quantile=0.8, n_bins=30))

# %%
SMOTETomek_efc = SMOTETomek_pipeline

# %%
SMOTETomek_efc.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('smotetomek',
#                  SMOTETomek(tomek=TomekLinks(sampling_strategy='majority'))),
#                 ('energybasedflowclassifier',
#                  EnergyBasedFlowClassifier(cutoff_quantile=0.8))])

# %%
new_params = {'energybasedflowclassifier__' + key: efc_params[key] for key in efc_params}

# %%
smote_tk_grid = GridSearchCV(SMOTETomek_pipeline, param_grid=new_params, cv=kf, scoring='recall', return_train_score=True)

# %%
smote_tk_grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=Pipeline(steps=[('smotetomek',
#                                         SMOTETomek(tomek=TomekLinks(sampling_strategy='majority'))),
#                                        ('energybasedflowclassifier',
#                                         EnergyBasedFlowClassifier(cutoff_quantile=0.8))]),
#              param_grid={'energybasedflowclassifier__cutoff_quantile': [0.7,
#                                                                         0.8,
#                                                                         0.9],
#                          'energybasedflowclassifier__n_bins': [10, 20, 30]},
#              return_train_score=True, scoring='recall')

# %%
print('Best parameters:', smote_tk_grid.best_params_)
print('Best score:', smote_tk_grid.best_score_)
# Out:
# Best parameters: {'energybasedflowclassifier__cutoff_quantile': 0.7, 'energybasedflowclassifier__n_bins': 20}
# Best score: 0.8563352191384537

# %%
y_pred = smote_tk_grid.predict(X_test)

# %%
# # ploting energies
# benign = np.where(y_test == 0)[0]
# malicious = np.where(y_test == 1)[0]

# benign_energies = y_energies[benign]
# malicious_energies = y_energies[malicious]
# cutoff = SMOTETomek_efc.estimators_[0].cutoff_

# bins = np.histogram(y_energies, bins=60)[1]

# plt.hist(
#     malicious_energies,
#     bins,
#     facecolor="#006680",
#     alpha=0.7,
#     ec="white",
#     linewidth=0.3,
#     label="malicious",
# )
# plt.hist(
#     benign_energies,
#     bins,
#     facecolor="#b3b3b3",
#     alpha=0.7,
#     ec="white",
#     linewidth=0.3,
#     label="benign",
# )
# plt.axvline(cutoff, color="r", linestyle="dashed", linewidth=1)
# plt.legend()

# plt.xlabel("Energy", fontsize=12)
# plt.ylabel("Density", fontsize=12)

# plt.savefig(f'{results_efc}/9_smote_with_grid_search_cv.png')

# %%
metric_dict_9 = {
    "Technique": "Combining SMOTE and Tomek Links",
    "accuracy": accuracy_score(y_test, y_pred),
    "f1": f1_score(y_test, y_pred, pos_label=1),
    "f1_micro": f1_score(y_test, y_pred, average="micro"),
    "f1_macro": f1_score(y_test, y_pred, average="macro"),
    "precision": precision_score(y_test, y_pred),
    "recall": recall_score(y_test, y_pred),
    "roc_auc": roc_auc_score(y_test, y_pred),
}

# %%
pprint(metric_dict_9)
# Out:
# {'Technique': 'Combining SMOTE and Tomek Links',
#  'accuracy': 0.6928418038654259,
#  'f1': np.float64(0.35926534269075705),
#  'f1_macro': np.float64(0.5786346955415843),
#  'f1_micro': np.float64(0.6928418038654259),
#  'precision': np.float64(0.22557659853740858),
#  'recall': np.float64(0.8819648093841642),
#  'roc_auc': np.float64(0.7771715209859104)}

# %%
df_efc_metrics.loc[9] = metric_dict_9
df_efc_metrics
# Out:
#                          Technique  accuracy        f1  f1_micro  f1_macro  \
# 0               Unbalanced Dataset  0.842891  0.003045  0.842891  0.458886
# 1                Unlabeled Dataset  0.260044       NaN  0.260044  0.169561
# 2                No Unlabeled Data  0.909238       NaN  0.909238  0.318326
# 3                 Balanced Dataset  0.767510  0.787676  0.767510  0.765394
# 4                            Smote  0.796684  0.809895  0.796684  0.795698
# 5                   Grid Search CV  0.649678  0.167970  0.649678  0.473050
# 6              Random Oversampling  0.688690  0.351766  0.688690  0.573462
# 7             Random Undersampling  0.472799  0.266361  0.472799  0.427466
# 8         Smote With GridSearch CV  0.691267  0.357324  0.691267  0.577079
# 9  Combining SMOTE and Tomek Links  0.692842  0.359265  0.692842  0.578635
#
#    precision    recall   roc_auc
# 0   0.002591  0.003693  0.452447
# 1        NaN       NaN       NaN
# 2        NaN       NaN       NaN
# 3   0.724584  0.862803  0.767545
# 4   0.760482  0.866175  0.796684
# 5   0.109340  0.362170  0.521479
# 6   0.220767  0.865103  0.767352
# 7   0.154121  0.980205  0.699051
# 8   0.224238  0.879032  0.774991
# 9   0.225577  0.881965  0.777172
