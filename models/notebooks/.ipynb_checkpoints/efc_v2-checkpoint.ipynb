# %% [markdown]
# ## EFC-Package

# %%
from math import ceil
from pprint import pprint

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import auc, classification_report, confusion_matrix, f1_score, roc_curve

# %%
from efc import EnergyBasedFlowClassifier

# %%
from research_aml_elliptic.src.reaml.model_performance import calculate_model_score
from research_aml_elliptic.src.experiments.general_functions.elliptic_data_preprocessing import run_elliptic_preprocessing_pipeline

# %%
from sklearn.metrics import (
    f1_score,
    accuracy_score,
    precision_score,
    recall_score,
    roc_auc_score,
)
from sklearn.model_selection import train_test_split

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
# Import Elliptic data set and set variables
last_time_step = 49
last_train_time_step = 34
only_labeled = True

# %% [markdown]
# ### Unsupervised Elliptic Data Set With EFC

# %%
# '1': 1, -> class1 (illicit)
# '2': 0, -> class2 (licit)
# 'unknown': 2 -> dropped
X_train, X_test, y_train, y_test = run_elliptic_preprocessing_pipeline(last_train_time_step=last_train_time_step,
                                                                             last_time_step=last_time_step,
                                                                             only_labeled=only_labeled)
# Out:
# /Users/kevinaraujo/repos/dissertation/PPCA-UnB-Dissertation/models/notebooks/research_aml_elliptic/src/experiments/general_functions/elliptic_data_preprocessing.py:46: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_classes.replace({"class": {"1": 1, "2": 0, "unknown": 2}}, inplace=True)

# %%
X_test.drop(['time_step'], axis=1)
# Out:
#        trans_feat_0  trans_feat_1  trans_feat_2  trans_feat_3  trans_feat_4  \
# 29894     -0.172982     -0.055242     -1.201369     -0.121970     -0.024025
# 29895     -0.166832     -0.115508      1.018602     -0.121970     -0.043875
# 29896     -0.167233     -0.115086      1.018602     -0.121970     -0.043875
# 29897     -0.172509     -0.120473     -0.091383     -0.121970     -0.043875
# 29898     -0.172805     -0.112290      1.018602     -0.121970     -0.063725
# ...             ...           ...           ...           ...           ...
# 46559     -0.159293     -0.037276      1.018602     -0.121970      0.035526
# 46560     -0.172962     -0.126566      1.018602     -0.121970     -0.063725
# 46561     -0.170412     -0.078164      1.018602      0.028105     -0.043875
# 46562     -0.093732     -0.116160      1.018602     -0.121970     -0.043875
# 46563     -0.172014     -0.078182      1.018602      0.028105     -0.043875
#
#        trans_feat_5  trans_feat_6  trans_feat_7  trans_feat_8  trans_feat_9  \
# 29894     -0.113002     -0.061584     -0.163642     -0.169456     -0.049707
# 29895     -0.113002     -0.061584     -0.157351     -0.163254     -0.049707
# 29896     -0.113002     -0.061584     -0.157761     -0.163658     -0.049707
# 29897     -0.113002     -0.061584     -0.163159     -0.168980     -0.049707
# 29898     -0.113002     -0.061584     -0.163461     -0.169278     -0.049707
# ...             ...           ...           ...           ...           ...
# 46559     -0.113002     -0.061584     -0.149635     -0.155646     -0.049707
# 46560     -0.113002     -0.061584     -0.163622     -0.169437     -0.049707
# 46561      0.054722     -0.061584     -0.163631     -0.167106     -0.032993
# 46562     -0.113002     -0.061584     -0.082559     -0.089510     -0.049707
# 46563      0.054722     -0.061584     -0.163626     -0.168778     -0.045389
#
#        ...  agg_feat_62  agg_feat_63  agg_feat_64  agg_feat_65  agg_feat_66  \
# 29894  ...    -0.577099    -0.626229     0.241128     0.241406    -0.216057
# 29895  ...    -0.532262    -0.575769    -0.979074    -0.978556     0.018279
# 29896  ...     1.283665     0.956938    -0.979074    -0.978556    -0.098889
# 29897  ...    -0.502370    -0.550539    -0.979074    -0.978556    -0.098889
# 29898  ...    -0.577099     0.004515     0.241128     0.241406     0.018279
# ...    ...          ...          ...          ...          ...          ...
# 46559  ...     1.793987     1.408971     0.231244    -0.388216    -0.098889
# 46560  ...    -0.577099     0.647874     0.241128     0.241406    10.914916
# 46561  ...     1.709623     1.606604     1.461330     1.461369     0.018279
# 46562  ...    -0.577099    -0.613614     0.241128     0.241406     0.018279
# 46563  ...     1.261246     1.985050     1.461330     1.461369     0.018279
#
#        agg_feat_67  agg_feat_68  agg_feat_69  agg_feat_70  agg_feat_71
# 29894    -0.125939    -0.131155    -0.269818    -0.120613    -0.119792
# 29895    -0.049041    -0.038193    -0.011377    -1.760926    -1.760984
# 29896    -0.087490    -0.084674    -0.140597     1.519700     1.521399
# 29897    -0.087490    -0.084674    -0.140597    -1.760926    -1.760984
# 29898    -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# ...            ...          ...          ...          ...          ...
# 46559     1.931078     3.168259     3.707301    -1.390548    -1.214035
# 46560     1.700384    -0.131155     7.914145    -0.120613    -0.119792
# 46561    -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# 46562    -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# 46563    -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
#
# [16670 rows x 165 columns]

# %%
X_train.drop(['time_step'], axis=1)
# Out:
#        trans_feat_0  trans_feat_1  trans_feat_2  trans_feat_3  trans_feat_4  \
# 0          0.163054      1.963790     -0.646376     12.409294     -0.063725
# 1         -0.005027      0.578941     -0.091383      4.380281     -0.063725
# 2         -0.147852     -0.184668     -1.201369     -0.121970     -0.043875
# 3         -0.151357     -0.184668     -1.201369     -0.121970     -0.043875
# 4         -0.172306     -0.184668     -1.201369      0.028105     -0.043875
# ...             ...           ...           ...           ...           ...
# 29889     -0.172968     -0.071395      0.463609     -0.121970     -0.043875
# 29890     -0.172924     -0.107411      1.018602     -0.121970     -0.063725
# 29891     -0.172897     -0.070152      0.463609     -0.121970     -0.043875
# 29892     -0.155367     -0.081852      0.463609     -0.121970     -0.043875
# 29893     -0.172981     -0.070152      0.463609     -0.121970     -0.043875
#
#        trans_feat_5  trans_feat_6  trans_feat_7  trans_feat_8  trans_feat_9  \
# 0          9.782742     12.414558     -0.163645     -0.115831      0.043598
# 1          4.667146      0.851305     -0.163645     -0.144554      0.020069
# 2         -0.113002     -0.061584     -0.137933     -0.144108     -0.049707
# 3         -0.113002     -0.061584     -0.141519     -0.147643     -0.049707
# 4         -0.029140      0.242712     -0.163640     -0.169115     -0.047227
# ...             ...           ...           ...           ...           ...
# 29889     -0.113002     -0.061584     -0.163627     -0.169442     -0.049707
# 29890     -0.113002     -0.061584     -0.163583     -0.169398     -0.049707
# 29891     -0.113002     -0.061584     -0.163555     -0.169371     -0.049707
# 29892     -0.113002     -0.061584     -0.145619     -0.151686     -0.049707
# 29893     -0.113002     -0.061584     -0.163641     -0.169455     -0.049707
#
#        ...  agg_feat_62  agg_feat_63  agg_feat_64  agg_feat_65  agg_feat_66  \
# 0      ...    -0.577099    -0.613614     0.241128     0.241406     1.072793
# 1      ...    -0.577099    -0.613614     0.241128     0.241406     0.604120
# 2      ...    -0.577099    -0.613614     0.241128     0.241406     0.018279
# 3      ...    -0.539735    -0.582077    -0.979074    -0.978556     0.018279
# 4      ...    -0.577099    -0.600999     0.241128     0.241406     0.018279
# ...    ...          ...          ...          ...          ...          ...
# 29889  ...     0.170195     1.266002     1.461330     1.461369    -0.098889
# 29890  ...    -0.577099     0.534340     0.241128     0.241406    -0.098889
# 29891  ...    -0.039047    -0.146863     1.461330     1.461369     0.018279
# 29892  ...    -0.577099    -0.613614     0.241128     0.241406     0.018279
# 29893  ...    -0.577099     0.635259     0.241128     0.241406    -0.098889
#
#        agg_feat_67  agg_feat_68  agg_feat_69  agg_feat_70  agg_feat_71
# 0         0.085530    -0.131155     0.677799    -0.120613    -0.119792
# 1         0.008632    -0.131155     0.333211    -0.120613    -0.119792
# 2        -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# 3        -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# 4        -0.068266    -0.084674    -0.054450    -1.760926    -1.760984
# ...            ...          ...          ...          ...          ...
# 29889    -0.106715    -0.131155    -0.183671    -0.120613    -0.119792
# 29890    -0.106715    -0.131155    -0.183671    -0.120613    -0.119792
# 29891    -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# 29892    -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# 29893    -0.106715    -0.131155    -0.183671    -0.120613    -0.119792
#
# [29894 rows x 165 columns]

# %%
len(y_train) + len(y_test)
# Out:
# 203769

# %%
len(np.where(y_train == 1)[0]) + len(np.where(y_test == 1)[0])
# Out:
# 4545

# %%
len(np.where(y_train == 0)[0]) + len(np.where(y_test == 0)[0])
# Out:
# 42019

# %%
len(np.where(y_train == 2)[0]) + len(np.where(y_test == 2)[0])
# Out:
# 157205

# %%
clf = EnergyBasedFlowClassifier(n_bins=30, cutoff_quantile=0.9)

# %%
clf.fit(X_train, y_train, base_class=0)
# Out:
# EnergyBasedFlowClassifier(cutoff_quantile=0.9)

# %%
y_pred, y_energies = clf.predict(X_test, return_energies=True)

# %%
# ploting energies
benign = np.where(y_test == 0)[0]
malicious = np.where(y_test == 1)[0]

benign_energies = y_energies[benign]
malicious_energies = y_energies[malicious]
cutoff = clf.estimators_[0].cutoff_

bins = np.histogram(y_energies, bins=60)[1]

plt.hist(
    malicious_energies,
    bins,
    facecolor="#006680",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="malicious",
)
plt.hist(
    benign_energies,
    bins,
    facecolor="#b3b3b3",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="benign",
)
plt.axvline(cutoff, color="r", linestyle="dashed", linewidth=1)
plt.legend()

plt.xlabel("Energy", fontsize=12)
plt.ylabel("Density", fontsize=12)

plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
print(roc_auc)
# Out:
# 0.4524465809250683

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[14047  1540]
#  [ 1079     4]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91     15587
#            1       0.00      0.00      0.00      1083
#
#     accuracy                           0.84     16670
#    macro avg       0.47      0.45      0.46     16670
# weighted avg       0.87      0.84      0.86     16670

# %%
f1 = f1_score(y_true=y_test,y_pred=y_pred)
f1

# %% [markdown]
# ### Including Unlabeled Data

# %%
# Import Elliptic data set and set variables
last_time_step = 49
last_train_time_step = 34
only_labeled
ans_feat_5  trans_feat_6  trans_feat_7  trans_feat_8  trans_feat_9  \
# 0          -0.113002     -0.061584     -0.162097     -0.167933     -0.049707
# 1          -0.113002     -0.061584     -0.162112     -0.167948     -0.049707
# 2          -0.113002     -0.061584     -0.162749     -0.168576     -0.049707
# 3           9.782742     12.414558     -0.163645     -0.115831      0.043598
# 4           1.312656     -0.061584     -0.163523      0.041399      0.935886
# ...              ...           ...           ...           ...           ...
# 136260      0.222447     -0.061584     -0.163645     -0.168382     -0.043072
# 136261     -0.113002     -0.061584     -0.163325     -0.169144     -0.049707
# 136262     -0.113002     -0.061584     -0.158687     -0.164571     -0.049707
# 136263     -0.113002     -0.061584     -0.163628     -0.169442     -0.049707
# 136264     -0.113002     -0.061584     -0.121796     -0.128197     -0.049707
#
#         ...  agg_feat_62  agg_feat_63  agg_feat_64  agg_feat_65  agg_feat_66  \
# 0       ...    -0.562153    -0.600999     1.461330     1.461369     0.018279
# 1       ...     0.947382     0.673103    -0.979074    -0.978556     0.018279
# 2       ...     0.670883     0.439728    -0.979074    -0.978556    -0.098889
# 3       ...    -0.577099    -0.613614     0.241128     0.241406     1.072793
# 4       ...    -0.511871    -0.400422     0.517257     0.579382     0.018279
# ...     ...          ...          ...          ...          ...          ...
# 136260  ...    -0.577099    -0.247782     0.241128     0.241406     0.018279
# 136261  ...    -0.479951    -0.493772     1.461330     1.461369    -0.098889
# 136262  ...    -0.293127    -0.361316     1.461330     1.461369    -0.098889
# 136263  ...    -0.278181     0.887556     1.461330     1.461369    -0.098889
# 136264  ...     0.910017     0.641566    -0.979074    -0.978556    -0.098889
#
#         agg_feat_67  agg_feat_68  agg_feat_69  agg_feat_70  agg_feat_71
# 0         -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# 1         -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# 2         -0.106715    -0.131155    -0.183671    -0.120613    -0.119792
# 3          0.085530    -0.131155     0.677799    -0.120613    -0.119792
# 4          0.277775     0.326394     1.293750     0.178136     0.179117
# ...             ...          ...          ...          ...          ...
# 136260    -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# 136261    -0.087490    -0.084674    -0.140597     1.519700     1.521399
# 136262    -0.087490    -0.084674    -0.140597    -1.760926    -1.760984
# 136263    -0.106715    -0.131155    -0.183671    -0.120613    -0.119792
# 136264    -0.087490    -0.084674    -0.140597     1.519700     1.521399
#
# [136265 rows x 165 columns]

# %%
clf = EnergyBasedFlowClassifier(n_bins=30, cutoff_quantile=0.9)

# %%
clf.fit(X_train, y_train, base_class=0)
# Out:
# EnergyBasedFlowClassifier(cutoff_quantile=0.9)

# %%
y_pred, y_energies = clf.predict(X_test, return_energies=True)

# %%
y_test
# Out:
# 136265    2
# 136266    2
# 136267    2
# 136268    2
# 136269    2
#          ..
# 203764    2
# 203765    2
# 203766    1
# 203767    2
# 203768    2
# Name: class, Length: 67504, dtype: int64

# %%
# ploting energies
benign = np.where(y_test == 0)[0]
malicious = np.where(y_test == 1)[0]

benign_energies = y_energies[benign]
malicious_energies = y_energies[malicious]
cutoff = clf.estimators_[0].cutoff_

bins = np.histogram(y_energies, bins=60)[1]

plt.hist(
    malicious_energies,
    bins,
    facecolor="#006680",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="malicious",
)
plt.hist(
    benign_energies,
    bins,
    facecolor="#b3b3b3",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="benign",
)
plt.axvline(cutoff, color="r", linestyle="dashed", linewidth=1)
plt.legend()

plt.xlabel("Energy", fontsize=12)
plt.ylabel("Density", fontsize=12)

plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test.values, y_pred)
roc_auc = auc(fpr, tpr)
print(roc_auc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 fpr, tpr, thresholds = roc_curve(y_test.values, y_pred)
#       2 roc_auc = auc(fpr, tpr)
#       3 print(roc_auc)
#
# File ~/.pyenv/versions/masters/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/.pyenv/versions/masters/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1145, in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#    1043 @validate_params(
#    1044     {
#    1045         "y_true": ["array-like"],
#    (...)
#    1054     y_true, y_score, *, pos_label=None, sample_weight=None, drop_intermediate=True
#    1055 ):
#    1056     """Compute Receiver operating characteristic (ROC).
#    1057
#    1058     Note: this implementation is restricted to the binary classification task.
#    (...)
#    1143     array([ inf, 0.8 , 0.4 , 0.35, 0.1 ])
#    1144     """
# -> 1145     fps, tps, thresholds = _binary_clf_curve(
#    1146         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight
#    1147     )
#    1149     # Attempt to drop thresholds corresponding to points in between and
#    1150     # collinear with other points. These are always suboptimal and do not
#    1151     # appear on a plotted ROC curve (and thus do not affect the AUC).
#    (...)
#    1156     # but does not drop more complicated cases like fps = [1, 3, 7],
#    1157     # tps = [1, 2, 4]; there is no harm in keeping too many thresholds.
#    1158     if drop_intermediate and len(fps) > 2:
#
# File ~/.pyenv/versions/masters/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:817, in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     815 y_type = type_of_target(y_true, input_name="y_true")
#     816 if not (y_type == "binary" or (y_type == "multiclass" and pos_label is not None)):
# --> 817     raise ValueError("{0} format is not supported".format(y_type))
#     819 check_consistent_length(y_true, y_score, sample_weight)
#     820 y_true = column_or_1d(y_true)
#
# ValueError: multiclass format is not supported

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[15559     0    28]
#  [ 1055    28     0]
#  [48866     1  1967]]
#               precision    recall  f1-score   support
#
#            0       0.24      1.00      0.38     15587
#            1       0.97      0.03      0.05      1083
#            2       0.99      0.04      0.07     50834
#
#     accuracy                           0.26     67504
#    macro avg       0.73      0.35      0.17     67504
# weighted avg       0.81      0.26      0.15     67504

# %%
f1 = f1_score(y_true=y_test,y_pred=y_pred)
f1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 f1 = f1_score(y_true=y_test,y_pred=y_pred)
#       2 f1
#
# File ~/.pyenv/versions/masters/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/.pyenv/versions/masters/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1279, in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1099 @validate_params(
#    1100     {
#    1101         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1126     zero_division="warn",
#    1127 ):
#    1128     """Compute the F1 score, also known as balanced F-score or F-measure.
#    1129
#    1130     The F1 score can be interpreted as a harmonic mean of the precision and
#    (...)
#    1277     array([0.66666667, 1.        , 0.66666667])
#    1278     """
# -> 1279     return fbeta_score(
#    1280         y_true,
#    1281         y_pred,
#    1282         beta=1,
#    1283         labels=labels,
#    1284         pos_label=pos_label,
#    1285         average=average,
#    1286         sample_weight=sample_weight,
#    1287         zero_division=zero_division,
#    1288     )
#
# File ~/.pyenv/versions/masters/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File ~/.pyenv/versions/masters/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1471, in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1291 @validate_params(
#    1292     {
#    1293         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1320     zero_division="warn",
#    1321 ):
#    1322     """Compute the F-beta score.
#    1323
#    1324     The F-beta score is the weighted harmonic mean of precision and recall,
#    (...)
#    1468     0.12...
#    1469     """
# -> 1471     _, _, f, _ = precision_recall_fscore_support(
#    1472         y_true,
#    1473         y_pred,
#    1474         beta=beta,
#    1475         labels=labels,
#    1476         pos_label=pos_label,
#    1477         average=average,
#    1478         warn_for=("f-score",),
#    1479         sample_weight=sample_weight,
#    1480         zero_division=zero_division,
#    1481     )
#    1482     return f
#
# File ~/.pyenv/versions/masters/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File ~/.pyenv/versions/masters/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1775, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1612 """Compute precision, recall, F-measure and support for each class.
#    1613
#    1614 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1772  array([2, 2, 2]))
#    1773 """
#    1774 _check_zero_division(zero_division)
# -> 1775 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1777 # Calculate tp_sum, pred_sum, true_sum ###
#    1778 samplewise = average == "samples"
#
# File ~/.pyenv/versions/masters/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1564, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1562         if y_type == "multiclass":
#    1563             average_options.remove("samples")
# -> 1564         raise ValueError(
#    1565             "Target is %s but average='binary'. Please "
#    1566             "choose another average setting, one of %r." % (y_type, average_options)
#    1567         )
#    1568 elif pos_label not in (None, 1):
#    1569     warnings.warn(
#    1570         "Note that pos_label (set to %r) is ignored when "
#    1571         "average != 'binary' (got %r). You may use "
#    (...)
#    1574         UserWarning,
#    1575     )
#
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].

# %% [markdown]
# ### Removing Unlabeled Data

# %%
# Import Elliptic data set and set variables
last_time_step = 49
last_train_time_step = 34
only_labeled = True

# %%
# '1': 1, -> class1 (illicit)
# '2': 0, -> class2 (licit)
# 'unknown': 2 -> dropped
X_train, X_test, y_train, y_test = run_elliptic_preprocessing_pipeline(last_train_time_step=last_train_time_step,
                                                                             last_time_step=last_time_step,
                                                                             only_labeled=only_labeled)
# Out:
# /Users/kevinaraujo/repos/dissertation/PPCA-UnB-Dissertation/models/notebooks/research_aml_elliptic/src/experiments/general_functions/elliptic_data_preprocessing.py:46: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_classes.replace({"class": {"1": 1, "2": 0, "unknown": 2}}, inplace=True)

# %%
X_test.drop(['time_step'], axis=1)
# Out:
#        trans_feat_0  trans_feat_1  trans_feat_2  trans_feat_3  trans_feat_4  \
# 29894     -0.172982     -0.055242     -1.201369     -0.121970     -0.024025
# 29895     -0.166832     -0.115508      1.018602     -0.121970     -0.043875
# 29896     -0.167233     -0.115086      1.018602     -0.121970     -0.043875
# 29897     -0.172509     -0.120473     -0.091383     -0.121970     -0.043875
# 29898     -0.172805     -0.112290      1.018602     -0.121970     -0.063725
# ...             ...           ...           ...           ...           ...
# 46559     -0.159293     -0.037276      1.018602     -0.121970      0.035526
# 46560     -0.172962     -0.126566      1.018602     -0.121970     -0.063725
# 46561     -0.170412     -0.078164      1.018602      0.028105     -0.043875
# 46562     -0.093732     -0.116160      1.018602     -0.121970     -0.043875
# 46563     -0.172014     -0.078182      1.018602      0.028105     -0.043875
#
#        trans_feat_5  trans_feat_6  trans_feat_7  trans_feat_8  trans_feat_9  \
# 29894     -0.113002     -0.061584     -0.163642     -0.169456     -0.049707
# 29895     -0.113002     -0.061584     -0.157351     -0.163254     -0.049707
# 29896     -0.113002     -0.061584     -0.157761     -0.163658     -0.049707
# 29897     -0.113002     -0.061584     -0.163159     -0.168980     -0.049707
# 29898     -0.113002     -0.061584     -0.163461     -0.169278     -0.049707
# ...             ...           ...           ...           ...           ...
# 46559     -0.113002     -0.061584     -0.149635     -0.155646     -0.049707
# 46560     -0.113002     -0.061584     -0.163622     -0.169437     -0.049707
# 46561      0.054722     -0.061584     -0.163631     -0.167106     -0.032993
# 46562     -0.113002     -0.061584     -0.082559     -0.089510     -0.049707
# 46563      0.054722     -0.061584     -0.163626     -0.168778     -0.045389
#
#        ...  agg_feat_62  agg_feat_63  agg_feat_64  agg_feat_65  agg_feat_66  \
#
...    -0.577099    -0.613614     0.241128     0.241406     0.018279
# 3      ...    -0.539735    -0.582077    -0.979074    -0.978556     0.018279
# 4      ...    -0.577099    -0.600999     0.241128     0.241406     0.018279
# ...    ...          ...          ...          ...          ...          ...
# 29889  ...     0.170195     1.266002     1.461330     1.461369    -0.098889
# 29890  ...    -0.577099     0.534340     0.241128     0.241406    -0.098889
# 29891  ...    -0.039047    -0.146863     1.461330     1.461369     0.018279
# 29892  ...    -0.577099    -0.613614     0.241128     0.241406     0.018279
# 29893  ...    -0.577099     0.635259     0.241128     0.241406    -0.098889
#
#        agg_feat_67  agg_feat_68  agg_feat_69  agg_feat_70  agg_feat_71
# 0         0.085530    -0.131155     0.677799    -0.120613    -0.119792
# 1         0.008632    -0.131155     0.333211    -0.120613    -0.119792
# 2        -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# 3        -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# 4        -0.068266    -0.084674    -0.054450    -1.760926    -1.760984
# ...            ...          ...          ...          ...          ...
# 29889    -0.106715    -0.131155    -0.183671    -0.120613    -0.119792
# 29890    -0.106715    -0.131155    -0.183671    -0.120613    -0.119792
# 29891    -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# 29892    -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# 29893    -0.106715    -0.131155    -0.183671    -0.120613    -0.119792
#
# [29894 rows x 165 columns]

# %%
# find unlabeled samples indexes in the training set
idx_abnormal = np.where(y_train == 2)[0]

# %%
X_train.drop(idx_abnormal, axis=0, inplace=True)

# %%
y_train.drop(idx_abnormal, axis=0, inplace=True)

# %%
len(X_train), len(y_train)
# Out:
# (29894, 29894)

# %%
clf = EnergyBasedFlowClassifier(n_bins=30, cutoff_quantile=0.9)

# %%
clf.fit(X_train, y_train, base_class=0)
# Out:
# EnergyBasedFlowClassifier(cutoff_quantile=0.9)

# %%
y_pred, y_energies = clf.predict(X_test, return_energies=True)

# %%
# ploting energies
benign = np.where(y_test == 0)[0]
malicious = np.where(y_test == 1)[0]

benign_energies = y_energies[benign]
malicious_energies = y_energies[malicious]
cutoff = clf.estimators_[0].cutoff_

bins = np.histogram(y_energies, bins=60)[1]

plt.hist(
    malicious_energies,
    bins,
    facecolor="#006680",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="malicious",
)
plt.hist(
    benign_energies,
    bins,
    facecolor="#b3b3b3",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="benign",
)
plt.axvline(cutoff, color="r", linestyle="dashed", linewidth=1)
plt.legend()

plt.xlabel("Energy", fontsize=12)
plt.ylabel("Density", fontsize=12)

plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
print(roc_auc)
# Out:
# 0.4524465809250683

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[14047  1540]
#  [ 1079     4]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91     15587
#            1       0.00      0.00      0.00      1083
#
#     accuracy                           0.84     16670
#    macro avg       0.47      0.45      0.46     16670
# weighted avg       0.87      0.84      0.86     16670

# %%
f1 = f1_score(y_true=y_test,y_pred=y_pred)
f1
# Out:
# np.float64(0.0030452988199467074)

# %%
# '1': 1, -> class1 (illicit)
# '2': 0, -> class2 (licit)
# 'unknown': 2 -> dropped
X_train_1, X_test_1, y_train_1, y_test_1 = run_elliptic_preprocessing_pipeline(last_train_time_step=last_train_time_step,
                                                                             last_time_step=last_time_step,
                                                                             only_labeled=only_labeled)

# %%
X_test.drop(['time_step'], axis=1)
X_train.drop(['time_step'], axis=1)

# %%
idx_abnormal = np.where(y_train_1 == 1)[0]  # find abnormal samples indexes in the training set
X_train_1.drop(idx_abnormal, axis=0, inplace=True)  # remove abnormal samples from training (EFC trains with only benign instances)
y_train_1.drop(idx_abnormal, axis=0, inplace=True)  # remove the corresponding abonrmal training targets

# %%
X_train_1

# %%
y_train_1

# %%
clf = EnergyBasedFlowClassifier(n_bins=10, cutoff_quantile=0.8)

# %%
clf.fit(X_train_1, y_train_1, base_class=0)

# %%
y_pred_1, y_energies_1 = clf.predict(X_test_1, return_energies=True)

# %%
fpr, tpr, thresholds = roc_curve(y_test_1, y_pred_1)
roc_auc = auc(fpr, tpr)
print(roc_auc)

# %%
print(confusion_matrix(y_test_1, y_pred_1))
print(classification_report(y_test_1, y_pred_1))

# %%
y_pred_1

# %% [markdown]
# ### Dealing With Unbalanced Dataset

# %%
# Import Elliptic data set and set variables
last_time_step = 49
last_train_time_step = 34
only_labeled = True

# %%
# '1': 1, -> class1 (illicit)
# '2': 0, -> class2 (licit)
# 'unknown': 2 -> dropped
X_train, X_test, y_train, y_test = run_elliptic_preprocessing_pipeline(last_train_time_step=last_train_time_step,
                                                                             last_time_step=last_time_step,
                                                                             only_labeled=only_labeled)
# Out:
# /Users/kevinaraujo/repos/dissertation/PPCA-UnB-Dissertation/models/notebooks/research_aml_elliptic/src/experiments/general_functions/elliptic_data_preprocessing.py:46: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_classes.replace({"class": {"1": 1, "2": 0, "unknown": 2}}, inplace=True)

# %%
df_train = pd.concat([X_train, y_train], axis=1)

# %%
df_test = pd.concat([X_test, y_test], axis=1)

# %%
df_train
# Out:
#        time_step  trans_feat_0  trans_feat_1  trans_feat_2  trans_feat_3  \
# 0              1      0.163054      1.963790     -0.646376     12.409294
# 1              1     -0.005027      0.578941     -0.091383      4.380281
# 2              1     -0.147852     -0.184668     -1.201369     -0.121970
# 3              1     -0.151357     -0.184668     -1.201369     -0.121970
# 4              1     -0.172306     -0.184668     -1.201369      0.028105
# ...          ...           ...           ...           ...           ...
# 29889         34     -0.172968     -0.071395      0.463609     -0.121970
# 29890         34     -0.172924     -0.107411      1.018602     -0.121970
# 29891         34     -0.172897     -0.070152      0.463609     -0.121970
# 29892         34     -0.155367     -0.081852      0.463609     -0.121970
# 29893         34     -0.172981     -0.070152      0.463609     -0.121970
#
#        trans_feat_4  trans_feat_5  trans_feat_6  trans_feat_7  trans_feat_8  \
#
#
#        ...  agg_feat_63  agg_feat_64  agg_feat_65  agg_feat_66  agg_feat_67  \
# 45936  ...     0.004515     1.461330     1.461369     0.018279    -0.087490
# 17491  ...    -0.500080     1.461330     1.461369     0.018279     0.066306
# 17389  ...    -0.600999     0.241128     0.241406     0.018279    -0.087490
# 10168  ...    -0.556847    -0.979074    -0.978556    -0.098889    -0.087490
# 1261   ...     0.944323    -0.979074    -0.978556    -0.098889    -0.087490
# ...    ...          ...          ...          ...          ...          ...
# 20735  ...    -0.613614     0.241128     0.241406    -0.098889    -0.087490
# 15951  ...    -0.525310     0.241128     0.241406     0.018279    -0.087490
# 2373   ...    -0.569462     1.461330     1.461369     0.018279    -0.087490
# 14247  ...    -0.607306     1.461330     1.461369     0.018279    -0.087490
# 30070  ...     0.610029     0.241128     0.241406     0.018279    -0.087490
#
#        agg_feat_68  agg_feat_69  agg_feat_70  agg_feat_71  class
# 45936    -0.131155    -0.097524    -0.120613    -0.119792      0
# 17491     0.240693     0.247064    -1.760926    -1.760984      0
# 17389    -0.131155    -0.097524    -0.120613    -0.119792      1
# 10168    -0.084674    -0.140597    -1.760926    -1.760984      0
# 1261     -0.084674    -0.140597     1.519700     1.521399      0
# ...            ...          ...          ...          ...    ...
# 20735    -0.084674    -0.140597    -1.760926    -1.760984      0
# 15951    -0.131155    -0.097524    -0.120613    -0.119792      1
# 2373     -0.131155    -0.097524    -0.120613    -0.119792      0
# 14247    -0.131155    -0.097524    -0.120613    -0.119792      0
# 30070    -0.131155    -0.097524    -0.120613    -0.119792      1
#
# [46564 rows x 167 columns]

# %%
df['class'].value_counts()
# Out:
# class
# 0    42019
# 1     4545
# Name: count, dtype: int64

# %%
# amount of ilicit classes 4545 rows.
ilicit_df = df.loc[df['class'] == 1]
licit_df = df.loc[df['class'] == 0][:4545]

# %%
normal_distributed_df = pd.concat([ilicit_df, licit_df])

# %%
# Shuffle dataframe rows
new_df = normal_distributed_df.sample(frac=1, random_state=42)

# %%
new_df.head()
# Out:
#        time_step  trans_feat_0  trans_feat_1  trans_feat_2  trans_feat_3  \
# 14195         13     -0.170339     -0.158783     -1.201369      -0.12197
# 33595         38     -0.172965     -0.118034      1.018602      -0.12197
# 30205         35     -0.172870     -0.109513      1.018602      -0.12197
# 16337         17     -0.172822     -0.157706      1.018602      -0.12197
# 15477         15     -0.172092     -0.158783     -1.201369      -0.12197
#
#        trans_feat_4  trans_feat_5  trans_feat_6  trans_feat_7  trans_feat_8  \
# 14195     -0.063725     -0.113002     -0.061584     -0.160940     -0.166792
# 33595     -0.063725     -0.113002     -0.061584     -0.163626     -0.169440
# 30205     -0.063725     -0.113002     -0.061584     -0.163528     -0.169345
# 16337     -0.063725     -0.113002     -0.061584     -0.163480     -0.169297
# 15477     -0.063725     -0.113002     -0.061584     -0.162733     -0.168561
#
#        ...  agg_feat_63  agg_feat_64  agg_feat_65  agg_feat_66  agg_feat_67  \
# 14195  ...     0.168508     0.241128     0.241406    -0.098889    -0.106715
# 33595  ...    -0.222553     0.241128     0.241406     0.018279    -0.087490
# 30205  ...    -0.537925     0.241128     0.241406     0.018279    -0.087490
# 16337  ...    -0.235168     0.241128     0.241406     0.018279    -0.087490
# 15477  ...    -0.600999     0.241128     0.241406     0.018279    -0.087490
#
#        agg_feat_68  agg_feat_69  agg_feat_70  agg_feat_71  class
# 14195    -0.131155    -0.183671    -0.120613    -0.119792      1
# 33595    -0.131155    -0.097524    -0.120613    -0.119792      1
# 30205    -0.131155    -0.097524    -0.120613    -0.119792      1
# 16337    -0.131155    -0.097524    -0.120613    -0.119792      1
# 15477    -0.131155    -0.097524    -0.120613    -0.119792      1
#
# [5 rows x 167 columns]

# %% [markdown]
# #### Equally Distributing and Correlating

# %%
print('Distribution of the Classes in the subsample dataset')
print(new_df['class'].value_counts()/len(new_df))



sns.countplot(x='class', data=new_df, palette=['red', 'blue'])
plt.title('Equally Distributed Classes', fontsize=14)
plt.show()
# Out:
# Distribution of the Classes in the subsample dataset
# class
# 1    0.5
# 0    0.5
# Name: count, dtype: float64
# /var/folders/8b/c9dvlw851kx2vf3r7gc5gbbh0000gn/T/ipykernel_50695/1450831521.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='class', data=new_df, palette=['red', 'blue'])

# %% [markdown]
# ### EFC With Balanced Dataset

# %%
new_df
# Out:
#        time_step  trans_feat_0  trans_feat_1  trans_feat_2  trans_feat_3  \
#
ans_feat_4  trans_feat_5  trans_feat_6  trans_feat_7  trans_feat_8  \
# 14195     -0.063725     -0.113002     -0.061584     -0.160940     -0.166792
# 33595     -0.063725     -0.113002     -0.061584     -0.163626     -0.169440
# 30205     -0.063725     -0.113002     -0.061584     -0.163528     -0.169345
# 16337     -0.063725     -0.113002     -0.061584     -0.163480     -0.169297
# 15477     -0.063725     -0.113002     -0.061584     -0.162733     -0.168561
# ...             ...           ...           ...           ...           ...
# 3742      -0.063725     -0.113002     -0.061584     -0.163526     -0.169343
# 10464     -0.043875      0.641758     -0.061584     -0.163627     -0.169442
# 2916      -0.043875     -0.029140     -0.061584     -0.163644     -0.168552
# 28041     -0.043875     -0.113002     -0.061584     -0.082855     -0.089802
# 19418      0.492076     -0.113002     -0.061584     -0.163466     -0.169283
#
#        ...  agg_feat_62  agg_feat_63  agg_feat_64  agg_feat_65  agg_feat_66  \
# 14195  ...    -0.577099     0.168508     0.241128     0.241406    -0.098889
# 33595  ...    -0.577099    -0.222553     0.241128     0.241406     0.018279
# 30205  ...    -0.577099    -0.537925     0.241128     0.241406     0.018279
# 16337  ...    -0.577099    -0.235168     0.241128     0.241406     0.018279
# 15477  ...    -0.577099    -0.600999     0.241128     0.241406     0.018279
# ...    ...          ...          ...          ...          ...          ...
# 3742   ...    -0.577099     0.900171     0.241128     0.241406     0.018279
# 10464  ...     2.748362     2.306729    -0.979074    -0.978556    -0.098889
# 2916   ...    -0.569626    -0.594691     1.461330     1.461369     0.018279
# 28041  ...    -0.577099    -0.613614     0.241128     0.241406     0.018279
# 19418  ...     1.531478     1.562001     0.454600     0.306889    -0.098889
#
#        agg_feat_67  agg_feat_68  agg_feat_69  agg_feat_70  agg_feat_71
# 14195    -0.106715    -0.131155    -0.183671    -0.120613    -0.119792
# 33595    -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# 30205    -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# 16337    -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# 15477    -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# ...            ...          ...          ...          ...          ...
# 3742     -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# 10464    -0.087490    -0.084674    -0.140597     1.519700     1.521399
# 2916     -0.068266    -0.084674    -0.054450    -1.760926    -1.760984
# 28041    -0.087490    -0.131155    -0.097524    -0.120613    -0.119792
# 19418    -0.087490    -0.102169    -0.162134     0.138989     0.139950
#
# [9090 rows x 166 columns]

# %%
y
# Out:
# 14195    1
# 33595    1
# 30205    1
# 16337    1
# 15477    1
#         ..
# 3742     0
# 10464    0
# 2916     0
# 28041    1
# 19418    0
# Name: class, Length: 9090, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=139, stratify=y, shuffle=True, test_size=0.3
)

# %%
clf = EnergyBasedFlowClassifier(n_bins=10, cutoff_quantile=0.85)

# %%
clf.fit(X_train, y_train, base_class=0)
# Out:
# EnergyBasedFlowClassifier(cutoff_quantile=0.85, n_bins=10)

# %%
y_pred, y_energies = clf.predict(X_test, return_energies=True)

# %%
# ploting energies
benign = np.where(y_test == 0)[0]
malicious = np.where(y_test == 1)[0]

benign_energies = y_energies[benign]
malicious_energies = y_energies[malicious]
cutoff = clf.estimators_[0].cutoff_

bins = np.histogram(y_energies, bins=60)[1]

plt.hist(
    malicious_energies,
    bins,
    facecolor="#006680",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="malicious",
)
plt.hist(
    benign_energies,
    bins,
    facecolor="#b3b3b3",
    alpha=0.7,
    ec="white",
    linewidth=0.3,
    label="benign",
)
plt.axvline(cutoff, color="r", linestyle="dashed", linewidth=1)
plt.legend()

plt.xlabel("Energy", fontsize=12)
plt.ylabel("Density", fontsize=12)

plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
print(roc_auc)
# Out:
# 0.7513705320547438

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[1042  322]
#  [ 356 1007]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.76      0.75      1364
#            1       0.76      0.74      0.75      1363
#
#     accuracy                           0.75      2727
#    macro avg       0.75      0.75      0.75      2727
# weighted avg       0.75      0.75      0.75      2727
