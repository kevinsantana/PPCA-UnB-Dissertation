# %% [markdown]
# ## Data Acquisition

# %%
from os import listdir
from os.path import isfile, join

import pandas as pd

# %%
def merge_dataset(data_files: str = "../../datasets", symbol: str = "btc"):
    files = [f for f in listdir(data_files) if isfile(join(data_files, f)) and f.startswith(symbol) and f.endswith('.parquet')]
    return pd.concat(
        pd.read_parquet(join(data_files, f), engine='fastparquet') for f in files
    )

# %%
def prepare_dataset(data_files: str = "../datasets", symbol: str = "btc", datetime_index: bool = True):
    df = merge_dataset(data_files=data_files, symbol=symbol)
    
    # timestamp to python datetime
    if datetime_index:
        df['date'] = pd.to_datetime(df['date'], unit='s')

    df = df.set_index(['date'])
    df.sort_index(inplace=True)

    return df

# %%
top_10_symbol = [
        'BTC-BRL', 'ETH-BRL', 'USDT-BRL', 'SOL-BRL', 'XRP-BRL',
        'USDC-BRL', 'DOGE-BRL', 'ADA-BRL', 'AVAX-BRL', 'SHIB-BRL'
    ]

# %%
def create_dataset():
    dataset = {}
    for pair in top_10_symbol:
        pair = pair.replace('-BRL', '').lower()
        dataset[pair] = prepare_dataset(symbol=pair)
    return dataset

# %%
def dataset_by_time_range(start_date='2023-01-01', end_date='2023-12-31', columns=['price', 'amount']):
    dataset = create_dataset()
    return {pair: dataset[pair].loc[f'{start_date}':f'{end_date}'][columns] for pair in dataset}

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# TBD

# %% [markdown]
# ## Models

# %% [markdown]
# ### Isolation Forest

# %%
import os

import numpy as np
from sklearn.ensemble import IsolationForest
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plotting Figures

# %%
def plot_outliers(model, df, pair, time_range, save_plot=True, save_df=True):
    model.fit(df)
    df['score'] = model.decision_function(df[['price', 'amount']])
    df['anomaly_value'] = model.predict(df[['price', 'amount']])
    # outliers
    outliers = df.loc[df['anomaly_value'] == -1]
    outliers_index = list(outliers.index)
    
    #datapoints classified as -1 are anomalous
    print(f'Total Number of Non-Outliers and Outliers {pair}: ', df['anomaly_value'].value_counts())
    fig = df['anomaly_value'].value_counts().plot(kind='bar',
                                                       xlabel='1 Normal Point -1 Anomaly Point',
                                                       ylabel='Total Transactions',
                                                       title=f'Total Number of Non-Outliers and Outliers {pair}').get_figure()

    if save_plot:
        try:
            os.makedirs(f'./iforest/figures/1{time_range}/{pair}')
        except FileExistsError:
            pass
        
        fig.savefig(f'./iforest/figures/1{time_range}/{pair}/{pair}-1{time_range}-outliers-count')

    if save_df:
        try:
            os.makedirs(f'./iforest/datasets/1{time_range}/{pair}')
        except FileExistsError:
            pass
        
        df.to_csv(f'./iforest/datasets/1{time_range}/{pair}/df_{pair}_anomaly.csv', index=True)  

    return outliers, outliers_index

# %%
def plot_detection(df, outliers, time_range, pair, save_fig=True):
    plt.figure(figsize = (32, 16))
    plt.plot(df[['price']], marker = '.')
    plt.plot(outliers[['price']], 'o', color = 'red', label = 'outlier')
    plt.title(f'Detection By Isolation Forest {pair}')
    
    #plt.grid()
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()

    if save_fig:
        try:
            os.makedirs(f'./iforest/figures/1{time_range}/{pair}')
        except FileExistsError:
            pass
    
        plt.savefig(f'./iforest/figures/1{time_range}/{pair}/{pair}-1{time_range}-detection-by-price-and-date')

# %%
def plot_figures(dataset, model, time_range):
    for pair in dataset:
        df_pair = dataset[pair]
        outliers, outliers_idx = plot_outliers(model, df=df_pair, pair=pair, time_range=time_range)
        plot_detection(df=df_pair, outliers=outliers, time_range=time_range, pair=pair)

# %% [markdown]
# #### 1 year dataset

# %%
#initiate the model with 0.05% contamination

model = IsolationForest(
    n_estimators=1_000,
    max_samples='auto',
    contamination=float(0.005),
    random_state=139,
    n_jobs=-1
)

# %%
dataset_by_year = dataset_by_time_range(start_date='2023-01-01',
                                        end_date='2023-12-31',
                                        columns=['price', 'amount'])
dataset_by_year['usdt']
plot_figures(dataset_by_year, model, time_range='year')
# Out:
# Total Number of Non-Outliers and Outliers btc:  anomaly_value
#  1    1275698
# -1       6411
# Name: count, dtype: int64
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[39], line 5
#       1 dataset_by_year = dataset_by_time_range(start_date='2023-01-01',
#       2                                         end_date='2023-12-31',
#       3                                         columns=['price', 'amount'])
#       4 dataset_by_year['usdt']
# ----> 5 plot_figures(dataset_by_year, model, time_range='year')
#
# Cell In[37], line 5, in plot_figures(dataset, model, time_range)
#       3 df_pair = dataset[pair]
#       4 outliers, outliers_idx = plot_outliers(model, df=df_pair, pair=pair, time_range=time_range)
# ----> 5 plot_detection(df=df_pair, outliers=outliers, time_range=time_range, pair=pair)
#
# Cell In[36], line 18, in plot_detection(df, outliers, time_range, pair, save_fig)
#      15 except FileExistsError:
#      16     pass
# ---> 18 plt.savefig(f'./iforest/figures/{time_range}/{pair}/{pair}-1{time_range}-detection-by-price-and-date')
#
# File ~/.pyenv/versions/masters/lib/python3.12/site-packages/matplotlib/pyplot.py:1223, in savefig(*args, **kwargs)
#    1220 fig = gcf()
#    1221 # savefig default implementation has no return, so mypy is unhappy
#    1222 # presumably this is here because subclasses can return?
# -> 1223 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1224 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1225 return res
#
# File ~/.pyenv/versions/masters/lib/python3.12/site-packages/matplotlib/figure.py:3388, in Figure.savefig(self, fname, transparent, **kwargs)
#    3386     for ax in self.axes:
#    3387         _recursively_make_axes_transparent(stack, ax)
# -> 3388 self.canvas.print_figure(fname, **kwargs)
#
# File ~/.pyenv/versions/masters/lib/python3.12/site-packages/matplotlib/backend_bases.py:2218, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2214 try:
#    2215     # _get_renderer may change the figure dpi (as vector formats
#    2216     # force the figure dpi to 72), so we need to set it again here.
#    2217     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2218         result = print_method(
#    2219             filename,
#    2220             facecolor=facecolor,
#    2221             edgecolor=edgecolor,
#    2222             orientation=orientation,
#    2223             bbox_inches_restore=_bbox_inches_restore,
#    2224             **kwargs)
#    2225 finally:
#    2226     if bbox_inches and restore_bbox:
#
# File ~/.pyenv/versions/masters/lib/python3.12/site-packages/matplotlib/backend_bases.py:2068, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2064     optional_kws = {  # Passed by print_figure for other renderers.
#    2065         "dpi", "facecolor", "edgecolor", "orientation",
#    2066         "bbox_inches_restore"}
#    2067     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2068     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2069         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2070 else:  # Let third-parties do as they see fit.
#    2071     print_method = meth
#
# File ~/.pyenv/versions/masters/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:496, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     449 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     450     """
#     451     Write the figure to a PNG file.
#     452
#    (...)
#     494         *metadata*, including the default 'Software' key.
#     495     """
# --> 496     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/.pyenv/versions/masters/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:445, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     440 """
#     441 Draw the canvas, then save it using `.image.imsave` (to which
#     442 *pil_kwargs* and *metadata* are forwarded).
#     443 """
#     444 FigureCanvasAgg.draw(self)
# --> 445 mpl.image.imsave(
#     446     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     447     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/.pyenv/versions/masters/lib/python3.12/site-packages/matplotlib/image.py:1676, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1674 pil_kwargs.setdefault("format", format)
#    1675 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1676 image.save(fname, **pil_kwargs)
#
# File ~/.pyenv/versions/masters/lib/python3.12/site-packages/PIL/Image.py:2563, in Image.save(self, fp, format, **params)
#    2561         fp = builtins.open(filename, "r+b")
#    2562     else:
# -> 2563         fp = builtins.open(filename, "w+b")
#    2564 else:
#    2565     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/kevinaraujo/repos/dissertation/PPCA-UnB-Dissertation/models/notebooks/iforest/figures/year/btc/btc-1year-detection-by-price-and-date.png'

# %% [markdown]
# #### 1 month dataset

# %%
#initiate the model with 0.05% contamination

model_month = IsolationForest(
    n_estimators=1_000,
    max_samples='auto',
    contamination=float(0.0005),
    random_state=139,
    n_jobs=-1
)

# %%
dataset_by_month = dataset_by_time_range(start_date='2023-12-01',
                                        end_date='2023-12-31',
                                        columns=['price', 'amount'])
plot_figures(dataset_by_month, model_month, time_range='month')

# %% [markdown]
# #### 1 day dataset

# %%
#initiate the model with 0.1% contamination

model_day = IsolationForest(
    n_estimators=1_000,
    max_samples='auto',
    contamination=float(0.001),
    random_state=139,
    n_jobs=-1
)

# %%
dataset_by_day = dataset_by_time_range(start_date='2023-12-13',
                                        end_date='2023-12-13',
                                        columns=['price', 'amount'])
plot_figures(dataset_by_day, model_day, time_range='day')

# %% [markdown]
# #### 1 hour dataset

# %%
#initiate the model with 1% contamination

model_hour = IsolationForest(
    n_estimators=1_000,
    max_samples='auto',
    contamination=float(0.1),
    random_state=139,
    n_jobs=-1
)

# %%
dataset_by_hour = dataset_by_time_range(start_date='2023-12-23 17:00:00',
                                        end_date='2023-12-23 17:59:59',
                                        columns=['price', 'amount'])
plot_figures(dataset_by_hour, model_hour, time_range='hour')
